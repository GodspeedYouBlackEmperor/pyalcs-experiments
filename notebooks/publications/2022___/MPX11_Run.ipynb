# %%
import os
import itertools
import numpy as np
from utils.run_utils import Runner

import gym
import gym_multiplexer
from gym_multiplexer.utils import get_correct_answer

from lcs import Perception
from lcs.agents.acs2 import ACS2, Configuration as CFG_ACS2
from lcs.agents.acs2er import ACS2ER, Configuration as CFG_ACS2ER, ReplayMemory, ReplayMemorySample
from lcs.metrics import population_metrics

# Logger
import logging
logging.basicConfig(level=logging.INFO)

# %% [markdown]
# # EXPERIMENT CONFIGURATION

# %%
BITS = 11 # 6 | 11 | 20 | 37
MPX = f'boolean-multiplexer-{BITS}bit-v0'
EXPLORE_TRIALS = 500
EXPLOIT_TRIALS = 100
METRICS_FREQUENCY = 1
KNOWLEDGE_STATE_SAMPLES = 1000 # applies only when 20 or 37 bits, otherwise all possible states verified

# The size of ER replay memory buffer
ER_BUFFER_SIZE = 10000
# The minimum number of samples of ER replay memory buffer to start replying samples (warm-up phase)
ER_BUFFER_MIN_SAMPLES = 50
# The number of samples to be replayed druing ER phase
ER_SAMPLES_NUMBER_LIST = [3]



#######

REPEAT_START = 1
REPEAT = 3

EXPERIMENT_NAME = "MPX11_TEST1" # Please edit if running new experiment to do not override saved results.

# %%
runner = Runner('MPX', EXPERIMENT_NAME, MPX)

# %% [markdown]
# ## METRICS

# %%
class MpxObservationWrapper(gym.ObservationWrapper):
    def observation(self, observation):
        return [str(x) for x in observation]
        
knowledge_env = MpxObservationWrapper(gym.make(MPX))

def get_transitions(states):
    transitions = list(map(lambda s: 
            (Perception([str(float(x)) for x in s] + ['0.0']), 
            get_correct_answer(list(s) + [0], knowledge_env.env.env.control_bits), 
            Perception([str(float(x)) for x in s] + ['1.0'])), 
        states))

    return transitions

def _mpx_knowledge(population, transitions, transitions_length) -> float:
    # Take into consideration only reliable classifiers
    reliable_classifiers = [c for c in population if c.is_reliable()]

    if(len(reliable_classifiers) == 0):
        return 0

    nr_correct = 0

    for p0, correct_answer, p1 in transitions:
        if any([True for cl in reliable_classifiers if
                cl.predicts_successfully(
                    p0,
                    correct_answer,
                    p1)]):

            nr_correct += 1

    return nr_correct / transitions_length

if BITS == 6 or BITS == 11: # Verify all 
    def get_all_transitions():
        states = list(itertools.product([0, 1], repeat=BITS))
        return get_transitions(states)

    TRANSITIONS = get_all_transitions()
    TRANSITIONS_LENGTH = len(TRANSITIONS)
    
    def mpx_knowledge(population) -> float:
        return _mpx_knowledge(population, TRANSITIONS, TRANSITIONS_LENGTH)

elif BITS == 20 or BITS == 37: # Verify samples
    def get_sampled_transitions():
        states = np.random.randint(2, size=(KNOWLEDGE_STATE_SAMPLES, BITS))
        return get_transitions(states)

    def mpx_knowledge(population) -> float:
        return _mpx_knowledge(population, get_sampled_transitions(), KNOWLEDGE_STATE_SAMPLES)
else:
    raise Exception(f'Unsupported BITS number: {BITS}')
    

def mpx_metrics(agent, env):
    metrics = {
        "knowledge": mpx_knowledge(agent.population)
    }
    metrics.update(population_metrics(agent.population, env))

    return metrics


def _weight_func_reward(rm: ReplayMemory, sample: ReplayMemorySample):
    if(sample.reward == 0):
        return 1
    
    return 5

def _weight_func_unique(rm: ReplayMemory, sample: ReplayMemorySample):
    existing_count = sum(1 for s in rm if sample.state == s.state and sample.action == s.action and sample.reward == s.reward and sample.next_state == s.next_state and sample.done == s.done)

    return 1 / (existing_count * 2 + 1)

# %% [markdown]
# ## EXPERIMENT

# %%
def _run_experiment(agent, path):
    runner.run_experiment(agent, MpxObservationWrapper(gym.make(MPX)), EXPLORE_TRIALS, EXPLOIT_TRIALS, path)
    
def run_acs2_experiment():
    for i in range(REPEAT_START, REPEAT_START + REPEAT):
        # Create agent 
        cfg = CFG_ACS2(
            classifier_length=knowledge_env.env.observation_space.n,
            number_of_possible_actions=2,
            do_ga=True,
            metrics_trial_frequency=METRICS_FREQUENCY,
            user_metrics_collector_fcn=mpx_metrics)
        agent = ACS2(cfg)

        _run_experiment(agent, f'{i}')

def _run_acs2er_experiment(er_samples_number: int):
    for i in range(REPEAT_START, REPEAT_START + REPEAT):
        # Create agent 
        cfg = CFG_ACS2ER(    
            classifier_length=knowledge_env.env.observation_space.n,
            number_of_possible_actions=2,
            do_ga=True,
            metrics_trial_frequency=METRICS_FREQUENCY,
            er_buffer_size=ER_BUFFER_SIZE,
            er_min_samples=ER_BUFFER_MIN_SAMPLES,
            er_samples_number=er_samples_number,
            user_metrics_collector_fcn=mpx_metrics)
        agent = ACS2ER(cfg)

        _run_experiment(agent, os.path.join(f'm_3-ER', f'{i}'))

def run_acs2er_experiments():
    for er_samples_number in ER_SAMPLES_NUMBER_LIST:
        print(f"START - ACS2ER - {er_samples_number}")
        _run_acs2er_experiment(er_samples_number)
        print(f"END - ACS2ER - {er_samples_number}")

def _run_acs2per_experiment(er_samples_number: int):
    for i in range(REPEAT_START, REPEAT_START + REPEAT):
        # Create agent 
        cfg = CFG_ACS2ER(    
            classifier_length=knowledge_env.env.observation_space.n,
            number_of_possible_actions=2,
            do_ga=True,
            metrics_trial_frequency=METRICS_FREQUENCY,
            er_buffer_size=ER_BUFFER_SIZE,
            er_min_samples=ER_BUFFER_MIN_SAMPLES,
            er_samples_number=er_samples_number,
            er_weight_function=_weight_func_reward,
            user_metrics_collector_fcn=mpx_metrics)
        agent = ACS2ER(cfg)

        _run_experiment(agent, os.path.join(f'm_3-pER_reward', f'{i}'))

def run_acs2per_experiments():
    for er_samples_number in ER_SAMPLES_NUMBER_LIST:
        print(f"START - ACS2pER - reward")
        _run_acs2per_experiment(er_samples_number)
        print(f"END - ACS2pER - reward")


def _run_acs2per2_experiment(er_samples_number: int):
    for i in range(REPEAT_START, REPEAT_START + REPEAT):
        # Create agent
        cfg = CFG_ACS2ER(    
            classifier_length=knowledge_env.env.observation_space.n,
            number_of_possible_actions=2,
            do_ga=True,
            metrics_trial_frequency=METRICS_FREQUENCY,
            er_buffer_size=ER_BUFFER_SIZE,
            er_min_samples=ER_BUFFER_MIN_SAMPLES,
            er_samples_number=er_samples_number,
            er_weight_function=_weight_func_unique,
            user_metrics_collector_fcn=mpx_metrics)
        agent = ACS2ER(cfg)

        _run_experiment(agent, os.path.join(f'm_3-pER_unique', f'{i}'))

def run_acs2per2_experiments():
    for er_samples_number in ER_SAMPLES_NUMBER_LIST:
        print(f"START - ACS2pER - unique")
        _run_acs2per2_experiment(er_samples_number)
        print(f"END - ACS2pER - unique")

# %% [markdown]
# ### RUN ACS2 Experiments

# %%
run_acs2_experiment()
# Out:
# INFO:lcs.agents.Agent:{'trial': 50, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.0017652999999882013, 'knowledge': 0, 'population': 94, 'numerosity': 94, 'reliable': 0}
# INFO:lcs.agents.Agent:{'trial': 100, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.001418299999983219, 'knowledge': 0, 'population': 195, 'numerosity': 195, 'reliable': 0}
# INFO:lcs.agents.Agent:{'trial': 150, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.007408300000008694, 'knowledge': 0, 'population': 323, 'numerosity': 323, 'reliable': 0}
# INFO:lcs.agents.Agent:{'trial': 200, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.0022011000000077274, 'knowledge': 0, 'population': 456, 'numerosity': 456, 'reliable': 0}
# INFO:lcs.agents.Agent:{'trial': 250, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.004123500000019931, 'knowledge': 0, 'population': 697, 'numerosity': 698, 'reliable': 0}
# INFO:lcs.agents.Agent:{'trial': 300, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.0039660999999853175, 'knowledge': 0, 'population': 900, 'numerosity': 901, 'reliable': 0}
# INFO:lcs.agents.Agent:{'trial': 350, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.0046311000000116564, 'knowledge': 0, 'population': 1219, 'numerosity': 1220, 'reliable': 0}
# INFO:lcs.agents.Agent:{'trial': 400, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.009102200000000948, 'knowledge': 0, 'population': 1444, 'numerosity': 1445, 'reliable': 0}
# INFO:lcs.agents.Agent:{'trial': 450, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.025536799999997584, 'knowledge': 0, 'population': 1852, 'numerosity': 1853, 'reliable': 0}
# INFO:lcs.agents.Agent:{'trial': 500, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.061783399999995936, 'knowledge': 0.109375, 'population': 2028, 'numerosity': 2030, 'reliable': 2}
# INFO:lcs.agents.Agent:{'trial': 10, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.008346599999981663, 'knowledge': 0.109375, 'population': 2028, 'numerosity': 2030, 'reliable': 2}
# INFO:lcs.agents.Agent:{'trial': 20, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.006954399999983707, 'knowledge': 0.109375, 'population': 2028, 'numerosity': 2030, 'reliable': 2}
# INFO:lcs.agents.Agent:{'trial': 30, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.007104099999992286, 'knowledge': 0.109375, 'population': 2028, 'numerosity': 2030, 'reliable': 2}
# INFO:lcs.agents.Agent:{'trial': 40, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.007065499999981739, 'knowledge': 0.109375, 'population': 2028, 'numerosity': 2030, 'reliable': 2}
# INFO:lcs.agents.Agent:{'trial': 50, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.007838099999986525, 'knowledge': 0.109375, 'population': 2028, 'numerosity': 2030, 'reliable': 2}
# INFO:lcs.agents.Agent:{'trial': 60, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.007181599999995569, 'knowledge': 0.109375, 'population': 2028, 'numerosity': 2030, 'reliable': 2}
# INFO:lcs.agents.Agent:{'trial': 70, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.007475399999975707, 'knowledge': 0.109375, 'population': 2028, 'numerosity': 2030, 'reliable': 2}
# INFO:lcs.agents.Agent:{'trial': 80, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.00950430000000324, 'knowledge': 0.109375, 'population': 2028, 'numerosity': 2030, 'reliable': 2}
# INFO:lcs.agents.Agent:{'trial': 90, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.008456200000011904, 'knowledge': 0.109375, 'population': 2028, 'numerosity': 2030, 'reliable': 2}
# INFO:lcs.agents.Agent:{'trial': 100, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.00706290000002241, 'knowledge': 0.109375, 'population': 2028, 'numerosity': 2030, 'reliable': 2}
# INFO:lcs.agents.Agent:{'trial': 50, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.0010581999999885738, 'knowledge': 0, 'population': 101, 'numerosity': 101, 'reliable': 0}
# INFO:lcs.agents.Agent:{'trial': 100, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.0029906999999980144, 'knowledge': 0, 'population': 265, 'numerosity': 265, 'reliable': 0}
# INFO:lcs.agents.Agent:{'trial': 150, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.0025424000000100477, 'knowledge': 0, 'population': 469, 'numerosity': 469, 'reliable': 0}
# INFO:lcs.agents.Agent:{'trial': 200, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.005196699999999055, 'knowledge': 0.00048828125, 'population': 637, 'numerosity': 637, 'reliable': 1}
# INFO:lcs.agents.Agent:{'trial': 250, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.005196400000016865, 'knowledge': 0.00048828125, 'population': 829, 'numerosity': 829, 'reliable': 1}
# INFO:lcs.agents.Agent:{'trial': 300, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.006817899999987276, 'knowledge': 0.0009765625, 'population': 1115, 'numerosity': 1115, 'reliable': 2}
# INFO:lcs.agents.Agent:{'trial': 350, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.00748730000000819, 'knowledge': 0.0009765625, 'population': 1326, 'numerosity': 1326, 'reliable': 2}
# INFO:lcs.agents.Agent:{'trial': 400, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.017557300000021314, 'knowledge': 0.00146484375, 'population': 1594, 'numerosity': 1594, 'reliable': 3}
# INFO:lcs.agents.Agent:{'trial': 450, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.01021710000000553, 'knowledge': 0.00146484375, 'population': 1811, 'numerosity': 1811, 'reliable': 4}
# INFO:lcs.agents.Agent:{'trial': 500, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.012517599999995355, 'knowledge': 0.15771484375, 'population': 2039, 'numerosity': 2039, 'reliable': 7}
# INFO:lcs.agents.Agent:{'trial': 10, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.007564500000000862, 'knowledge': 0.15771484375, 'population': 2039, 'numerosity': 2039, 'reliable': 7}
# INFO:lcs.agents.Agent:{'trial': 20, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.008439900000013267, 'knowledge': 0.15771484375, 'population': 2039, 'numerosity': 2039, 'reliable': 7}
# INFO:lcs.agents.Agent:{'trial': 30, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.009114799999991874, 'knowledge': 0.15771484375, 'population': 2039, 'numerosity': 2039, 'reliable': 7}
# INFO:lcs.agents.Agent:{'trial': 40, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.007582700000000386, 'knowledge': 0.15771484375, 'population': 2039, 'numerosity': 2039, 'reliable': 7}
# INFO:lcs.agents.Agent:{'trial': 50, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.008141700000010132, 'knowledge': 0.15771484375, 'population': 2039, 'numerosity': 2039, 'reliable': 7}
# INFO:lcs.agents.Agent:{'trial': 60, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.0076422000000206936, 'knowledge': 0.15771484375, 'population': 2039, 'numerosity': 2039, 'reliable': 7}
# INFO:lcs.agents.Agent:{'trial': 70, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.008388099999990573, 'knowledge': 0.15771484375, 'population': 2039, 'numerosity': 2039, 'reliable': 7}
# INFO:lcs.agents.Agent:{'trial': 80, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.00962749999999346, 'knowledge': 0.15771484375, 'population': 2039, 'numerosity': 2039, 'reliable': 7}
# INFO:lcs.agents.Agent:{'trial': 90, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.008274400000004789, 'knowledge': 0.15771484375, 'population': 2039, 'numerosity': 2039, 'reliable': 7}
# INFO:lcs.agents.Agent:{'trial': 100, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.00788259999998786, 'knowledge': 0.15771484375, 'population': 2039, 'numerosity': 2039, 'reliable': 7}
# INFO:lcs.agents.Agent:{'trial': 50, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.002052700000007235, 'knowledge': 0, 'population': 80, 'numerosity': 80, 'reliable': 0}
# INFO:lcs.agents.Agent:{'trial': 100, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.0018248000000085085, 'knowledge': 0, 'population': 291, 'numerosity': 291, 'reliable': 0}
# INFO:lcs.agents.Agent:{'trial': 150, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.008427600000004531, 'knowledge': 0, 'population': 568, 'numerosity': 568, 'reliable': 0}
# INFO:lcs.agents.Agent:{'trial': 200, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.008329799999984289, 'knowledge': 0.00048828125, 'population': 818, 'numerosity': 818, 'reliable': 1}
# INFO:lcs.agents.Agent:{'trial': 250, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.006538199999994276, 'knowledge': 0.06298828125, 'population': 1032, 'numerosity': 1032, 'reliable': 2}
# INFO:lcs.agents.Agent:{'trial': 300, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.010642399999994723, 'knowledge': 0.06298828125, 'population': 1356, 'numerosity': 1356, 'reliable': 2}
# INFO:lcs.agents.Agent:{'trial': 350, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.008229400000004716, 'knowledge': 0.15673828125, 'population': 1417, 'numerosity': 1419, 'reliable': 4}
# INFO:lcs.agents.Agent:{'trial': 400, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.008290799999997489, 'knowledge': 0.21923828125, 'population': 1449, 'numerosity': 1452, 'reliable': 5}
# INFO:lcs.agents.Agent:{'trial': 450, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.007895099999984723, 'knowledge': 0.21923828125, 'population': 1657, 'numerosity': 1663, 'reliable': 5}
# INFO:lcs.agents.Agent:{'trial': 500, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.02113800000000765, 'knowledge': 0.25048828125, 'population': 1888, 'numerosity': 1893, 'reliable': 6}
# INFO:lcs.agents.Agent:{'trial': 10, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.007078000000007023, 'knowledge': 0.25048828125, 'population': 1888, 'numerosity': 1893, 'reliable': 6}
# INFO:lcs.agents.Agent:{'trial': 20, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.006988599999999678, 'knowledge': 0.25048828125, 'population': 1888, 'numerosity': 1893, 'reliable': 6}
# INFO:lcs.agents.Agent:{'trial': 30, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.007656999999994696, 'knowledge': 0.25048828125, 'population': 1888, 'numerosity': 1893, 'reliable': 6}
# INFO:lcs.agents.Agent:{'trial': 40, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.0074678000000005795, 'knowledge': 0.25048828125, 'population': 1888, 'numerosity': 1893, 'reliable': 6}
# INFO:lcs.agents.Agent:{'trial': 50, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.00828290000001175, 'knowledge': 0.25048828125, 'population': 1888, 'numerosity': 1893, 'reliable': 6}
# INFO:lcs.agents.Agent:{'trial': 60, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.0074850000000026284, 'knowledge': 0.25048828125, 'population': 1888, 'numerosity': 1893, 'reliable': 6}
# INFO:lcs.agents.Agent:{'trial': 70, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.00809959999998, 'knowledge': 0.25048828125, 'population': 1888, 'numerosity': 1893, 'reliable': 6}
# INFO:lcs.agents.Agent:{'trial': 80, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.0065409000000045125, 'knowledge': 0.25048828125, 'population': 1888, 'numerosity': 1893, 'reliable': 6}
# INFO:lcs.agents.Agent:{'trial': 90, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.008646199999986948, 'knowledge': 0.25048828125, 'population': 1888, 'numerosity': 1893, 'reliable': 6}
# INFO:lcs.agents.Agent:{'trial': 100, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.006339700000012272, 'knowledge': 0.25048828125, 'population': 1888, 'numerosity': 1893, 'reliable': 6}

# %% [markdown]
# ### RUN ACS2ER Experiments

# %%
run_acs2er_experiments()
# Out:
# INFO:lcs.agents.Agent:{'trial': 50, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.0008976000000018303, 'knowledge': 0, 'population': 3, 'numerosity': 3, 'reliable': 0}
# START - ACS2ER - 3
# INFO:lcs.agents.Agent:{'trial': 100, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.02106679999999983, 'knowledge': 0, 'population': 564, 'numerosity': 564, 'reliable': 0}
# INFO:lcs.agents.Agent:{'trial': 150, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.04771809999999732, 'knowledge': 0.00146484375, 'population': 1328, 'numerosity': 1328, 'reliable': 5}
# INFO:lcs.agents.Agent:{'trial': 200, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.08851490000000695, 'knowledge': 0.25341796875, 'population': 2365, 'numerosity': 2365, 'reliable': 45}
# INFO:lcs.agents.Agent:{'trial': 250, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.11666439999999056, 'knowledge': 0.42919921875, 'population': 3118, 'numerosity': 3118, 'reliable': 84}
# INFO:lcs.agents.Agent:{'trial': 300, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.11896439999998165, 'knowledge': 0.47021484375, 'population': 3763, 'numerosity': 3765, 'reliable': 103}
# INFO:lcs.agents.Agent:{'trial': 350, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.13201500000002397, 'knowledge': 0.71044921875, 'population': 3903, 'numerosity': 3907, 'reliable': 134}
# INFO:lcs.agents.Agent:{'trial': 400, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.10795799999999645, 'knowledge': 0.80908203125, 'population': 3192, 'numerosity': 3200, 'reliable': 189}
# INFO:lcs.agents.Agent:{'trial': 450, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.07669219999996812, 'knowledge': 0.7919921875, 'population': 2645, 'numerosity': 2660, 'reliable': 205}
# INFO:lcs.agents.Agent:{'trial': 500, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.07861739999998463, 'knowledge': 0.83349609375, 'population': 2483, 'numerosity': 2504, 'reliable': 225}
# INFO:lcs.agents.Agent:{'trial': 10, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.015618100000097002, 'knowledge': 0.83349609375, 'population': 2483, 'numerosity': 2504, 'reliable': 225}
# INFO:lcs.agents.Agent:{'trial': 20, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.010078999999905136, 'knowledge': 0.83349609375, 'population': 2483, 'numerosity': 2504, 'reliable': 225}
# INFO:lcs.agents.Agent:{'trial': 30, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.009177099999988059, 'knowledge': 0.83349609375, 'population': 2483, 'numerosity': 2504, 'reliable': 225}
# INFO:lcs.agents.Agent:{'trial': 40, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.020107600000073944, 'knowledge': 0.83349609375, 'population': 2483, 'numerosity': 2504, 'reliable': 225}
# INFO:lcs.agents.Agent:{'trial': 50, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.010549800000035248, 'knowledge': 0.83349609375, 'population': 2483, 'numerosity': 2504, 'reliable': 225}
# INFO:lcs.agents.Agent:{'trial': 60, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.00943250000000262, 'knowledge': 0.83349609375, 'population': 2483, 'numerosity': 2504, 'reliable': 225}
# INFO:lcs.agents.Agent:{'trial': 70, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.009888700000033168, 'knowledge': 0.83349609375, 'population': 2483, 'numerosity': 2504, 'reliable': 225}
# INFO:lcs.agents.Agent:{'trial': 80, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.010077500000079453, 'knowledge': 0.83349609375, 'population': 2483, 'numerosity': 2504, 'reliable': 225}
# INFO:lcs.agents.Agent:{'trial': 90, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.011399699999969926, 'knowledge': 0.83349609375, 'population': 2483, 'numerosity': 2504, 'reliable': 225}
# INFO:lcs.agents.Agent:{'trial': 100, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.011042200000019875, 'knowledge': 0.83349609375, 'population': 2483, 'numerosity': 2504, 'reliable': 225}
# INFO:lcs.agents.Agent:{'trial': 50, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.0007049999999253487, 'knowledge': 0, 'population': 2, 'numerosity': 2, 'reliable': 0}
# INFO:lcs.agents.Agent:{'trial': 100, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.010414200000013807, 'knowledge': 0, 'population': 235, 'numerosity': 235, 'reliable': 0}
# INFO:lcs.agents.Agent:{'trial': 150, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.049460599999974875, 'knowledge': 0.00146484375, 'population': 845, 'numerosity': 845, 'reliable': 3}
# INFO:lcs.agents.Agent:{'trial': 200, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.06668379999996432, 'knowledge': 0.00439453125, 'population': 1893, 'numerosity': 1893, 'reliable': 10}
# INFO:lcs.agents.Agent:{'trial': 250, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.1153690999999526, 'knowledge': 0.24951171875, 'population': 3195, 'numerosity': 3195, 'reliable': 43}
# INFO:lcs.agents.Agent:{'trial': 300, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.16577910000000884, 'knowledge': 0.4287109375, 'population': 3993, 'numerosity': 3994, 'reliable': 69}
# INFO:lcs.agents.Agent:{'trial': 350, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.2838574999999537, 'knowledge': 0.59228515625, 'population': 4211, 'numerosity': 4217, 'reliable': 97}
# INFO:lcs.agents.Agent:{'trial': 400, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.17350120000003244, 'knowledge': 0.712890625, 'population': 4368, 'numerosity': 4372, 'reliable': 135}
# INFO:lcs.agents.Agent:{'trial': 450, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.10622730000000047, 'knowledge': 0.74169921875, 'population': 3632, 'numerosity': 3643, 'reliable': 166}
# INFO:lcs.agents.Agent:{'trial': 500, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.10552220000010948, 'knowledge': 0.8125, 'population': 3561, 'numerosity': 3579, 'reliable': 212}
# INFO:lcs.agents.Agent:{'trial': 10, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.014263000000028114, 'knowledge': 0.8125, 'population': 3561, 'numerosity': 3579, 'reliable': 212}
# INFO:lcs.agents.Agent:{'trial': 20, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.012635700000032557, 'knowledge': 0.8125, 'population': 3561, 'numerosity': 3579, 'reliable': 212}
# INFO:lcs.agents.Agent:{'trial': 30, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.013378299999999399, 'knowledge': 0.8125, 'population': 3561, 'numerosity': 3579, 'reliable': 212}
# INFO:lcs.agents.Agent:{'trial': 40, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.03150080000000344, 'knowledge': 0.8125, 'population': 3561, 'numerosity': 3579, 'reliable': 212}
# INFO:lcs.agents.Agent:{'trial': 50, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.013349899999866466, 'knowledge': 0.8125, 'population': 3561, 'numerosity': 3579, 'reliable': 212}
# INFO:lcs.agents.Agent:{'trial': 60, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.013875499999812746, 'knowledge': 0.8125, 'population': 3561, 'numerosity': 3579, 'reliable': 212}
# INFO:lcs.agents.Agent:{'trial': 70, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.015454399999953239, 'knowledge': 0.8125, 'population': 3561, 'numerosity': 3579, 'reliable': 212}
# INFO:lcs.agents.Agent:{'trial': 80, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.012356299999964904, 'knowledge': 0.8125, 'population': 3561, 'numerosity': 3579, 'reliable': 212}
# INFO:lcs.agents.Agent:{'trial': 90, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.014259100000117542, 'knowledge': 0.8125, 'population': 3561, 'numerosity': 3579, 'reliable': 212}
# INFO:lcs.agents.Agent:{'trial': 100, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.015246200000092358, 'knowledge': 0.8125, 'population': 3561, 'numerosity': 3579, 'reliable': 212}
# INFO:lcs.agents.Agent:{'trial': 50, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.00126870000008239, 'knowledge': 0, 'population': 2, 'numerosity': 2, 'reliable': 0}
# INFO:lcs.agents.Agent:{'trial': 100, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.020333700000037425, 'knowledge': 0.0, 'population': 393, 'numerosity': 393, 'reliable': 1}
# INFO:lcs.agents.Agent:{'trial': 150, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.09085559999994075, 'knowledge': 0.34423828125, 'population': 1225, 'numerosity': 1225, 'reliable': 11}
# INFO:lcs.agents.Agent:{'trial': 200, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.12840040000014596, 'knowledge': 0.47705078125, 'population': 2206, 'numerosity': 2206, 'reliable': 32}
# INFO:lcs.agents.Agent:{'trial': 250, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.13164019999999255, 'knowledge': 0.65869140625, 'population': 3232, 'numerosity': 3233, 'reliable': 69}
# INFO:lcs.agents.Agent:{'trial': 300, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.10730499999999665, 'knowledge': 0.64794921875, 'population': 3090, 'numerosity': 3095, 'reliable': 92}
# INFO:lcs.agents.Agent:{'trial': 350, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.09772459999999228, 'knowledge': 0.736328125, 'population': 3117, 'numerosity': 3126, 'reliable': 129}
# INFO:lcs.agents.Agent:{'trial': 400, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.1402619999998933, 'knowledge': 0.75537109375, 'population': 3738, 'numerosity': 3751, 'reliable': 156}
# INFO:lcs.agents.Agent:{'trial': 450, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.1360837999998239, 'knowledge': 0.78515625, 'population': 3502, 'numerosity': 3519, 'reliable': 169}
# INFO:lcs.agents.Agent:{'trial': 500, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.13872849999984282, 'knowledge': 0.880859375, 'population': 2989, 'numerosity': 3021, 'reliable': 169}
# INFO:lcs.agents.Agent:{'trial': 10, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.011538900000005015, 'knowledge': 0.880859375, 'population': 2989, 'numerosity': 3021, 'reliable': 169}
# INFO:lcs.agents.Agent:{'trial': 20, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.012008500000092681, 'knowledge': 0.880859375, 'population': 2989, 'numerosity': 3021, 'reliable': 169}
# INFO:lcs.agents.Agent:{'trial': 30, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.013180299999930867, 'knowledge': 0.880859375, 'population': 2989, 'numerosity': 3021, 'reliable': 169}
# INFO:lcs.agents.Agent:{'trial': 40, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.012765700000045399, 'knowledge': 0.880859375, 'population': 2989, 'numerosity': 3021, 'reliable': 169}
# INFO:lcs.agents.Agent:{'trial': 50, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.013200600000118357, 'knowledge': 0.880859375, 'population': 2989, 'numerosity': 3021, 'reliable': 169}
# INFO:lcs.agents.Agent:{'trial': 60, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.014486500000202795, 'knowledge': 0.880859375, 'population': 2989, 'numerosity': 3021, 'reliable': 169}
# INFO:lcs.agents.Agent:{'trial': 70, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.015754300000025978, 'knowledge': 0.880859375, 'population': 2989, 'numerosity': 3021, 'reliable': 169}
# INFO:lcs.agents.Agent:{'trial': 80, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.013554500000054759, 'knowledge': 0.880859375, 'population': 2989, 'numerosity': 3021, 'reliable': 169}
# INFO:lcs.agents.Agent:{'trial': 90, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.015512600000192833, 'knowledge': 0.880859375, 'population': 2989, 'numerosity': 3021, 'reliable': 169}
# INFO:lcs.agents.Agent:{'trial': 100, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.012305700000069919, 'knowledge': 0.880859375, 'population': 2989, 'numerosity': 3021, 'reliable': 169}
# END - ACS2ER - 3

# %%
run_acs2per_experiments()
# Out:
# INFO:lcs.agents.Agent:{'trial': 50, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.0007014999998773419, 'knowledge': 0, 'population': 3, 'numerosity': 3, 'reliable': 0}
# START - ACS2pER - reward
# INFO:lcs.agents.Agent:{'trial': 100, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.02769650000004731, 'knowledge': 0.65625, 'population': 404, 'numerosity': 404, 'reliable': 7}
# INFO:lcs.agents.Agent:{'trial': 150, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.04367879999995239, 'knowledge': 0.82275390625, 'population': 824, 'numerosity': 824, 'reliable': 57}
# INFO:lcs.agents.Agent:{'trial': 200, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.036965900000041074, 'knowledge': 0.8681640625, 'population': 1042, 'numerosity': 1043, 'reliable': 122}
# INFO:lcs.agents.Agent:{'trial': 250, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.0733989999998812, 'knowledge': 0.92236328125, 'population': 1010, 'numerosity': 1014, 'reliable': 171}
# INFO:lcs.agents.Agent:{'trial': 300, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.035982600000124876, 'knowledge': 0.9580078125, 'population': 950, 'numerosity': 960, 'reliable': 168}
# INFO:lcs.agents.Agent:{'trial': 350, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.050102700000024925, 'knowledge': 0.9580078125, 'population': 1227, 'numerosity': 1239, 'reliable': 209}
# INFO:lcs.agents.Agent:{'trial': 400, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.06617289999985587, 'knowledge': 0.9931640625, 'population': 1443, 'numerosity': 1455, 'reliable': 229}
# INFO:lcs.agents.Agent:{'trial': 450, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.18241050000005998, 'knowledge': 0.998046875, 'population': 1740, 'numerosity': 1754, 'reliable': 330}
# INFO:lcs.agents.Agent:{'trial': 500, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.12645089999978154, 'knowledge': 0.99755859375, 'population': 1749, 'numerosity': 1766, 'reliable': 326}
# INFO:lcs.agents.Agent:{'trial': 10, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.009089800000310788, 'knowledge': 0.99755859375, 'population': 1749, 'numerosity': 1766, 'reliable': 326}
# INFO:lcs.agents.Agent:{'trial': 20, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.00955470000008063, 'knowledge': 0.99755859375, 'population': 1749, 'numerosity': 1766, 'reliable': 326}
# INFO:lcs.agents.Agent:{'trial': 30, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.007911700000022392, 'knowledge': 0.99755859375, 'population': 1749, 'numerosity': 1766, 'reliable': 326}
# INFO:lcs.agents.Agent:{'trial': 40, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.009595900000022084, 'knowledge': 0.99755859375, 'population': 1749, 'numerosity': 1766, 'reliable': 326}
# INFO:lcs.agents.Agent:{'trial': 50, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.0077092999999877065, 'knowledge': 0.99755859375, 'population': 1749, 'numerosity': 1766, 'reliable': 326}
# INFO:lcs.agents.Agent:{'trial': 60, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.010540100000071106, 'knowledge': 0.99755859375, 'population': 1749, 'numerosity': 1766, 'reliable': 326}
# INFO:lcs.agents.Agent:{'trial': 70, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.01007819999995263, 'knowledge': 0.99755859375, 'population': 1749, 'numerosity': 1766, 'reliable': 326}
# INFO:lcs.agents.Agent:{'trial': 80, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.00851650000004156, 'knowledge': 0.99755859375, 'population': 1749, 'numerosity': 1766, 'reliable': 326}
# INFO:lcs.agents.Agent:{'trial': 90, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.008726400000341528, 'knowledge': 0.99755859375, 'population': 1749, 'numerosity': 1766, 'reliable': 326}
# INFO:lcs.agents.Agent:{'trial': 100, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.009594200000265118, 'knowledge': 0.99755859375, 'population': 1749, 'numerosity': 1766, 'reliable': 326}
# INFO:lcs.agents.Agent:{'trial': 50, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.0014845000000605069, 'knowledge': 0, 'population': 3, 'numerosity': 3, 'reliable': 0}
# INFO:lcs.agents.Agent:{'trial': 100, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.02040019999958531, 'knowledge': 0.52392578125, 'population': 397, 'numerosity': 397, 'reliable': 7}
# INFO:lcs.agents.Agent:{'trial': 150, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.05875200000036784, 'knowledge': 0.89013671875, 'population': 1225, 'numerosity': 1225, 'reliable': 82}
# INFO:lcs.agents.Agent:{'trial': 200, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.0758453999997073, 'knowledge': 0.9599609375, 'population': 1710, 'numerosity': 1710, 'reliable': 193}
# INFO:lcs.agents.Agent:{'trial': 250, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.07508089999964795, 'knowledge': 0.98876953125, 'population': 1526, 'numerosity': 1528, 'reliable': 234}
# INFO:lcs.agents.Agent:{'trial': 300, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.09043169999995371, 'knowledge': 0.998046875, 'population': 1691, 'numerosity': 1694, 'reliable': 308}
# INFO:lcs.agents.Agent:{'trial': 350, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.1532087999999021, 'knowledge': 0.9931640625, 'population': 1657, 'numerosity': 1662, 'reliable': 361}
# INFO:lcs.agents.Agent:{'trial': 400, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.07692560000032245, 'knowledge': 0.99755859375, 'population': 1708, 'numerosity': 1718, 'reliable': 331}
# INFO:lcs.agents.Agent:{'trial': 450, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.10244030000012572, 'knowledge': 1.0, 'population': 2156, 'numerosity': 2165, 'reliable': 352}
# INFO:lcs.agents.Agent:{'trial': 500, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.0995017000000189, 'knowledge': 1.0, 'population': 1711, 'numerosity': 1722, 'reliable': 371}
# INFO:lcs.agents.Agent:{'trial': 10, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.007369299999936629, 'knowledge': 1.0, 'population': 1711, 'numerosity': 1722, 'reliable': 371}
# INFO:lcs.agents.Agent:{'trial': 20, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.008386500000142405, 'knowledge': 1.0, 'population': 1711, 'numerosity': 1722, 'reliable': 371}
# INFO:lcs.agents.Agent:{'trial': 30, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.013495400000010704, 'knowledge': 1.0, 'population': 1711, 'numerosity': 1722, 'reliable': 371}
# INFO:lcs.agents.Agent:{'trial': 40, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.008220299999720737, 'knowledge': 1.0, 'population': 1711, 'numerosity': 1722, 'reliable': 371}
# INFO:lcs.agents.Agent:{'trial': 50, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.008563299999877927, 'knowledge': 1.0, 'population': 1711, 'numerosity': 1722, 'reliable': 371}
# INFO:lcs.agents.Agent:{'trial': 60, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.008243099999617698, 'knowledge': 1.0, 'population': 1711, 'numerosity': 1722, 'reliable': 371}
# INFO:lcs.agents.Agent:{'trial': 70, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.008830199999920296, 'knowledge': 1.0, 'population': 1711, 'numerosity': 1722, 'reliable': 371}
# INFO:lcs.agents.Agent:{'trial': 80, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.00844569999981104, 'knowledge': 1.0, 'population': 1711, 'numerosity': 1722, 'reliable': 371}
# INFO:lcs.agents.Agent:{'trial': 90, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.009645199999795295, 'knowledge': 1.0, 'population': 1711, 'numerosity': 1722, 'reliable': 371}
# INFO:lcs.agents.Agent:{'trial': 100, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.00883190000013201, 'knowledge': 1.0, 'population': 1711, 'numerosity': 1722, 'reliable': 371}
# INFO:lcs.agents.Agent:{'trial': 50, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.0014562000001205888, 'knowledge': 0, 'population': 3, 'numerosity': 3, 'reliable': 0}
# INFO:lcs.agents.Agent:{'trial': 100, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.023428899999998976, 'knowledge': 0.46875, 'population': 358, 'numerosity': 358, 'reliable': 7}
# INFO:lcs.agents.Agent:{'trial': 150, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.04843329999994239, 'knowledge': 0.79296875, 'population': 567, 'numerosity': 567, 'reliable': 51}
# INFO:lcs.agents.Agent:{'trial': 200, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.03908020000017132, 'knowledge': 0.849609375, 'population': 776, 'numerosity': 776, 'reliable': 76}
# INFO:lcs.agents.Agent:{'trial': 250, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.07385019999992437, 'knowledge': 0.94091796875, 'population': 1228, 'numerosity': 1230, 'reliable': 125}
# INFO:lcs.agents.Agent:{'trial': 300, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.09413499999982378, 'knowledge': 0.9462890625, 'population': 1791, 'numerosity': 1793, 'reliable': 187}
# INFO:lcs.agents.Agent:{'trial': 350, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.0700633999999809, 'knowledge': 0.96240234375, 'population': 1639, 'numerosity': 1644, 'reliable': 244}
# INFO:lcs.agents.Agent:{'trial': 400, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.11566130000028352, 'knowledge': 0.98193359375, 'population': 1668, 'numerosity': 1675, 'reliable': 293}
# INFO:lcs.agents.Agent:{'trial': 450, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.09859350000078848, 'knowledge': 0.9912109375, 'population': 1813, 'numerosity': 1822, 'reliable': 318}
# INFO:lcs.agents.Agent:{'trial': 500, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.15831770000022516, 'knowledge': 0.98828125, 'population': 1555, 'numerosity': 1566, 'reliable': 289}
# INFO:lcs.agents.Agent:{'trial': 10, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.006751300000360061, 'knowledge': 0.98828125, 'population': 1555, 'numerosity': 1566, 'reliable': 289}
# INFO:lcs.agents.Agent:{'trial': 20, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.007374200000413111, 'knowledge': 0.98828125, 'population': 1555, 'numerosity': 1566, 'reliable': 289}
# INFO:lcs.agents.Agent:{'trial': 30, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.007398300000204472, 'knowledge': 0.98828125, 'population': 1555, 'numerosity': 1566, 'reliable': 289}
# INFO:lcs.agents.Agent:{'trial': 40, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.00687130000005709, 'knowledge': 0.98828125, 'population': 1555, 'numerosity': 1566, 'reliable': 289}
# INFO:lcs.agents.Agent:{'trial': 50, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.009621899999729067, 'knowledge': 0.98828125, 'population': 1555, 'numerosity': 1566, 'reliable': 289}
# INFO:lcs.agents.Agent:{'trial': 60, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.008536399999684363, 'knowledge': 0.98828125, 'population': 1555, 'numerosity': 1566, 'reliable': 289}
# INFO:lcs.agents.Agent:{'trial': 70, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.008519899999555491, 'knowledge': 0.98828125, 'population': 1555, 'numerosity': 1566, 'reliable': 289}
# INFO:lcs.agents.Agent:{'trial': 80, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.007829499999388645, 'knowledge': 0.98828125, 'population': 1555, 'numerosity': 1566, 'reliable': 289}
# INFO:lcs.agents.Agent:{'trial': 90, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.007073499999933119, 'knowledge': 0.98828125, 'population': 1555, 'numerosity': 1566, 'reliable': 289}
# INFO:lcs.agents.Agent:{'trial': 100, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.006930699999429635, 'knowledge': 0.98828125, 'population': 1555, 'numerosity': 1566, 'reliable': 289}
# END - ACS2pER - reward

# %%
run_acs2per2_experiments()
# Out:
# INFO:lcs.agents.Agent:{'trial': 50, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.0029211999999461113, 'knowledge': 0, 'population': 2, 'numerosity': 2, 'reliable': 0}
# START - ACS2pER - unique
# INFO:lcs.agents.Agent:{'trial': 100, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.0408873999995194, 'knowledge': 0, 'population': 456, 'numerosity': 456, 'reliable': 0}
# INFO:lcs.agents.Agent:{'trial': 150, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.07748759999958565, 'knowledge': 0.0791015625, 'population': 1462, 'numerosity': 1462, 'reliable': 6}
# INFO:lcs.agents.Agent:{'trial': 200, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.1126853999994637, 'knowledge': 0.44287109375, 'population': 2398, 'numerosity': 2398, 'reliable': 42}
# INFO:lcs.agents.Agent:{'trial': 250, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.11873509999986709, 'knowledge': 0.52880859375, 'population': 3265, 'numerosity': 3267, 'reliable': 92}
# INFO:lcs.agents.Agent:{'trial': 300, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.1139885000002323, 'knowledge': 0.619140625, 'population': 3957, 'numerosity': 3961, 'reliable': 120}
# INFO:lcs.agents.Agent:{'trial': 350, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.11104579999937414, 'knowledge': 0.70068359375, 'population': 3881, 'numerosity': 3889, 'reliable': 171}
# INFO:lcs.agents.Agent:{'trial': 400, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.12105560000054538, 'knowledge': 0.76904296875, 'population': 3501, 'numerosity': 3521, 'reliable': 205}
# INFO:lcs.agents.Agent:{'trial': 450, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.09139999999933934, 'knowledge': 0.77294921875, 'population': 3067, 'numerosity': 3097, 'reliable': 226}
# INFO:lcs.agents.Agent:{'trial': 500, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.2416364999999132, 'knowledge': 0.79345703125, 'population': 2421, 'numerosity': 2459, 'reliable': 235}
# INFO:lcs.agents.Agent:{'trial': 10, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.010865500000363681, 'knowledge': 0.79345703125, 'population': 2421, 'numerosity': 2459, 'reliable': 235}
# INFO:lcs.agents.Agent:{'trial': 20, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.00997079999979178, 'knowledge': 0.79345703125, 'population': 2421, 'numerosity': 2459, 'reliable': 235}
# INFO:lcs.agents.Agent:{'trial': 30, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.01026929999989079, 'knowledge': 0.79345703125, 'population': 2421, 'numerosity': 2459, 'reliable': 235}
# INFO:lcs.agents.Agent:{'trial': 40, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.010690199999771721, 'knowledge': 0.79345703125, 'population': 2421, 'numerosity': 2459, 'reliable': 235}
# INFO:lcs.agents.Agent:{'trial': 50, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.00938049999967916, 'knowledge': 0.79345703125, 'population': 2421, 'numerosity': 2459, 'reliable': 235}
# INFO:lcs.agents.Agent:{'trial': 60, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.010746699999799603, 'knowledge': 0.79345703125, 'population': 2421, 'numerosity': 2459, 'reliable': 235}
# INFO:lcs.agents.Agent:{'trial': 70, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.014581700000235287, 'knowledge': 0.79345703125, 'population': 2421, 'numerosity': 2459, 'reliable': 235}
# INFO:lcs.agents.Agent:{'trial': 80, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.012254900000698399, 'knowledge': 0.79345703125, 'population': 2421, 'numerosity': 2459, 'reliable': 235}
# INFO:lcs.agents.Agent:{'trial': 90, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.01055259999975533, 'knowledge': 0.79345703125, 'population': 2421, 'numerosity': 2459, 'reliable': 235}
# INFO:lcs.agents.Agent:{'trial': 100, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.009170699999231147, 'knowledge': 0.79345703125, 'population': 2421, 'numerosity': 2459, 'reliable': 235}
# INFO:lcs.agents.Agent:{'trial': 50, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.0019341999995958759, 'knowledge': 0, 'population': 3, 'numerosity': 3, 'reliable': 0}
# INFO:lcs.agents.Agent:{'trial': 100, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.027794300000095973, 'knowledge': 0.0, 'population': 415, 'numerosity': 415, 'reliable': 1}
# INFO:lcs.agents.Agent:{'trial': 150, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.07099890000063169, 'knowledge': 0.07861328125, 'population': 1459, 'numerosity': 1459, 'reliable': 7}
# INFO:lcs.agents.Agent:{'trial': 200, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.14368190000004688, 'knowledge': 0.43212890625, 'population': 2774, 'numerosity': 2774, 'reliable': 33}
# INFO:lcs.agents.Agent:{'trial': 250, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.11755809999976918, 'knowledge': 0.63330078125, 'population': 3615, 'numerosity': 3618, 'reliable': 89}
# INFO:lcs.agents.Agent:{'trial': 300, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.10419230000024982, 'knowledge': 0.66845703125, 'population': 3137, 'numerosity': 3146, 'reliable': 118}
# INFO:lcs.agents.Agent:{'trial': 350, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.18242430000009335, 'knowledge': 0.75244140625, 'population': 2895, 'numerosity': 2909, 'reliable': 133}
# INFO:lcs.agents.Agent:{'trial': 400, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.08453250000002299, 'knowledge': 0.7587890625, 'population': 2316, 'numerosity': 2339, 'reliable': 163}
# INFO:lcs.agents.Agent:{'trial': 450, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.15620829999988928, 'knowledge': 0.84423828125, 'population': 2185, 'numerosity': 2211, 'reliable': 161}
# INFO:lcs.agents.Agent:{'trial': 500, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.0795298000002731, 'knowledge': 0.93017578125, 'population': 2363, 'numerosity': 2395, 'reliable': 182}
# INFO:lcs.agents.Agent:{'trial': 10, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.010082199999487784, 'knowledge': 0.93017578125, 'population': 2363, 'numerosity': 2395, 'reliable': 182}
# INFO:lcs.agents.Agent:{'trial': 20, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.009841099999903236, 'knowledge': 0.93017578125, 'population': 2363, 'numerosity': 2395, 'reliable': 182}
# INFO:lcs.agents.Agent:{'trial': 30, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.013966999999865948, 'knowledge': 0.93017578125, 'population': 2363, 'numerosity': 2395, 'reliable': 182}
# INFO:lcs.agents.Agent:{'trial': 40, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.010756700000456476, 'knowledge': 0.93017578125, 'population': 2363, 'numerosity': 2395, 'reliable': 182}
# INFO:lcs.agents.Agent:{'trial': 50, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.01137139999991632, 'knowledge': 0.93017578125, 'population': 2363, 'numerosity': 2395, 'reliable': 182}
# INFO:lcs.agents.Agent:{'trial': 60, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.010425800000120944, 'knowledge': 0.93017578125, 'population': 2363, 'numerosity': 2395, 'reliable': 182}
# INFO:lcs.agents.Agent:{'trial': 70, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.012872399999650952, 'knowledge': 0.93017578125, 'population': 2363, 'numerosity': 2395, 'reliable': 182}
# INFO:lcs.agents.Agent:{'trial': 80, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.011299300000246149, 'knowledge': 0.93017578125, 'population': 2363, 'numerosity': 2395, 'reliable': 182}
# INFO:lcs.agents.Agent:{'trial': 90, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.010022999999819149, 'knowledge': 0.93017578125, 'population': 2363, 'numerosity': 2395, 'reliable': 182}
# INFO:lcs.agents.Agent:{'trial': 100, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.010073000000375032, 'knowledge': 0.93017578125, 'population': 2363, 'numerosity': 2395, 'reliable': 182}
# INFO:lcs.agents.Agent:{'trial': 50, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.009063599999535654, 'knowledge': 0, 'population': 3, 'numerosity': 3, 'reliable': 0}
# INFO:lcs.agents.Agent:{'trial': 100, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.026413700000375684, 'knowledge': 0.15625, 'population': 569, 'numerosity': 569, 'reliable': 1}
# INFO:lcs.agents.Agent:{'trial': 150, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.10565539999970497, 'knowledge': 0.45361328125, 'population': 1439, 'numerosity': 1439, 'reliable': 19}
# INFO:lcs.agents.Agent:{'trial': 200, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.13024070000028587, 'knowledge': 0.75244140625, 'population': 2553, 'numerosity': 2553, 'reliable': 62}
# INFO:lcs.agents.Agent:{'trial': 250, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.12808979999954317, 'knowledge': 0.8330078125, 'population': 3065, 'numerosity': 3065, 'reliable': 103}
# INFO:lcs.agents.Agent:{'trial': 300, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.24356119999993098, 'knowledge': 0.880859375, 'population': 3584, 'numerosity': 3585, 'reliable': 136}
# INFO:lcs.agents.Agent:{'trial': 350, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.09789639999962674, 'knowledge': 0.90478515625, 'population': 3208, 'numerosity': 3210, 'reliable': 164}
# INFO:lcs.agents.Agent:{'trial': 400, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.10937510000076145, 'knowledge': 0.9306640625, 'population': 2407, 'numerosity': 2413, 'reliable': 179}
# INFO:lcs.agents.Agent:{'trial': 450, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.05871709999973973, 'knowledge': 0.9521484375, 'population': 2066, 'numerosity': 2077, 'reliable': 196}
# INFO:lcs.agents.Agent:{'trial': 500, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.09547029999976075, 'knowledge': 0.94580078125, 'population': 2472, 'numerosity': 2487, 'reliable': 191}
# INFO:lcs.agents.Agent:{'trial': 10, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.010874599999624479, 'knowledge': 0.94580078125, 'population': 2472, 'numerosity': 2487, 'reliable': 191}
# INFO:lcs.agents.Agent:{'trial': 20, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.011988099999143742, 'knowledge': 0.94580078125, 'population': 2472, 'numerosity': 2487, 'reliable': 191}
# INFO:lcs.agents.Agent:{'trial': 30, 'steps_in_trial': 1, 'reward': 0, 'perf_time': 0.011761299999307084, 'knowledge': 0.94580078125, 'population': 2472, 'numerosity': 2487, 'reliable': 191}
# INFO:lcs.agents.Agent:{'trial': 40, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.01242420000016864, 'knowledge': 0.94580078125, 'population': 2472, 'numerosity': 2487, 'reliable': 191}
# INFO:lcs.agents.Agent:{'trial': 50, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.011975899999924877, 'knowledge': 0.94580078125, 'population': 2472, 'numerosity': 2487, 'reliable': 191}
# INFO:lcs.agents.Agent:{'trial': 60, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.011617000000114786, 'knowledge': 0.94580078125, 'population': 2472, 'numerosity': 2487, 'reliable': 191}
# INFO:lcs.agents.Agent:{'trial': 70, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.010679099999833852, 'knowledge': 0.94580078125, 'population': 2472, 'numerosity': 2487, 'reliable': 191}
# INFO:lcs.agents.Agent:{'trial': 80, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.012260399999831861, 'knowledge': 0.94580078125, 'population': 2472, 'numerosity': 2487, 'reliable': 191}
# INFO:lcs.agents.Agent:{'trial': 90, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.013671599999725004, 'knowledge': 0.94580078125, 'population': 2472, 'numerosity': 2487, 'reliable': 191}
# INFO:lcs.agents.Agent:{'trial': 100, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.011838899999929708, 'knowledge': 0.94580078125, 'population': 2472, 'numerosity': 2487, 'reliable': 191}
# END - ACS2pER - unique
