# %%
import os
from collections import defaultdict
from utils.run_utils import Runner

import gym
import gym_maze

from lcs.agents import Agent
from lcs.agents.acs2 import ACS2, Configuration as CFG_ACS2, ClassifiersList
from lcs.agents.acs2er import ACS2ER, Configuration as CFG_ACS2ER, ReplayMemory, ReplayMemorySample
from lcs.agents.acs2rer import ACS2RER, Configuration as CFG_ACS2RER
from lcs.metrics import population_metrics

# Logger
import logging
logging.basicConfig(level=logging.INFO)

# %% [markdown]
# # EXPERIMENT CONFIGURATION

# %%
MAZE = "Maze5-v0" 
EXPLORE_TRIALS = 200
EXPLOIT_TRIALS = 200

# The size of ER replay memory buffer
ER_BUFFER_SIZE = 10000
# The minimum number of samples of ER replay memory buffer to start replying samples (warm-up phase)
ER_BUFFER_MIN_SAMPLES = 100
# The number of samples to be replayed druing ER phase
ER_SAMPLES_NUMBER_LIST = [3]


#######

REPEAT_START = 1
REPEAT = 3

EXPERIMENT_NAME = "Maze5_TEST30" # Please edit if running new experiment to do not override saved results.

# %%
runner = Runner('MAZE', EXPERIMENT_NAME, MAZE)

# %% [markdown]
# ## METRICS

# %%
MAZE_PATH = 0
MAZE_REWARD = 9

optimal_paths_env = gym.make(MAZE)
matrix = optimal_paths_env.matrix
X = matrix.shape[1]
Y = matrix.shape[0]

def get_reward_pos():
    for i in range(Y):
        for j in range(X):
            if(matrix[i, j] == MAZE_REWARD):
                return(i, j)

def get_possible_neighbour_cords(pos_y, pos_x):
    n = ((pos_y - 1, pos_x), 4)
    ne = ((pos_y - 1, pos_x + 1), 5)
    e = ((pos_y, pos_x + 1), 6)
    se = ((pos_y + 1, pos_x + 1), 7)
    s = ((pos_y + 1, pos_x), 0)
    sw = ((pos_y + 1, pos_x - 1), 1)
    w = ((pos_y, pos_x - 1), 2)
    nw = ((pos_y - 1, pos_x - 1), 3)

    return [n, ne, e, se, s, sw, w, nw]

    
optimal_actions = []

root_node = get_reward_pos()

def is_included(cords, level):
    return any(op_cords[0] == cords[0] and op_cords[1] == cords[1] and level != op_level for op_cords, _, op_level in optimal_actions)


def get_optimal_actions_to(node, level):
    neighbour_cords = get_possible_neighbour_cords(node[0], node[1])

    next_level_cords = []
    for (pos_y, pos_x), action in neighbour_cords:
        if (not is_included((pos_y, pos_x), level)) and matrix[pos_y, pos_x] == MAZE_PATH:
            optimal_actions.append(((pos_y, pos_x), action, level))
            next_level_cords.append((pos_y, pos_x))

    return next_level_cords

LEVEL = 0
next_level_cords = get_optimal_actions_to(root_node, LEVEL)

while len(next_level_cords) > 0:
    LEVEL += 1
    new_next_level_cords = []
    for nlc in next_level_cords:
        new_next_level_cords += get_optimal_actions_to(nlc, LEVEL)

    next_level_cords = new_next_level_cords

positions_actions = defaultdict(set)
for cords, a, _ in optimal_actions: positions_actions[cords].add(a)

positions_actions = positions_actions.items()
POSITIONS_OPTIMAL_ACTIONS = list(map(lambda pa: (optimal_paths_env.env.maze.perception(pa[0]), list(pa[1])), positions_actions))
POSITIONS_OPTIMAL_ACTIONS_LENGTH = len(POSITIONS_OPTIMAL_ACTIONS)



def _maze_optimal(classifiers) -> float:
    nr_correct = 0

    for p0, optimal_actions_list in POSITIONS_OPTIMAL_ACTIONS:
        match_set = classifiers.form_match_set(p0)
        cl = match_set.get_best_classifier()

        if cl is not None and optimal_actions_list.count(cl.action) > 0:
            nr_correct += 1

    return nr_correct / POSITIONS_OPTIMAL_ACTIONS_LENGTH * 100.0


def _maze_optimal_reliable(classifiers) -> float:
    return _maze_optimal(ClassifiersList(*[c for c in classifiers if c.is_reliable()]))

# %%
def _get_transitions():
    knowledge_env = gym.make(MAZE)
    transitions = knowledge_env.env.get_transitions()
    transitions = list(map(lambda t: [knowledge_env.env.maze.perception(t[0]), t[1], knowledge_env.env.maze.perception(t[2])], transitions))

    return transitions

TRANSITIONS = _get_transitions()
TRANSITIONS_LENGTH = len(TRANSITIONS)

def _maze_knowledge(population) -> float:
    # Take into consideration only reliable classifiers
    reliable_classifiers = [c for c in population if c.is_reliable()]

    # Count how many transitions are anticipated correctly
    nr_correct = 0

    # For all possible destinations from each path cell
    for p0, action, p1 in TRANSITIONS:
        if any([True for cl in reliable_classifiers
                if cl.predicts_successfully(p0, action, p1)]):
            nr_correct += 1

    return nr_correct / TRANSITIONS_LENGTH * 100.0

def _maze_specificity(population) -> float:
    pop_len = len(population)
    if(pop_len) == 0:
        return 0
    return sum(map(lambda c: c.specificity, population)) / pop_len

def _maze_metrics(agent, env):
    pop = agent.population
    metrics = {
        'knowledge': _maze_knowledge(pop),
        "specificity": _maze_specificity(agent.population),
        "optimal": _maze_optimal(agent.population),
        "optimal_reliable": _maze_optimal_reliable(agent.population)
    }
    metrics.update(population_metrics(pop, env))
    
    return metrics

def _weight_func_reward(rm: ReplayMemory, sample: ReplayMemorySample):
    if(sample.reward == 0):
        return 1
    
    return 5

def _weight_func_unique(rm: ReplayMemory, sample: ReplayMemorySample):
    existing_count = sum(1 for s in rm if sample.state == s.state and sample.action == s.action and sample.reward == s.reward and sample.next_state == s.next_state and sample.done == s.done)

    return 1 / (existing_count * 2 + 1)

def _weight_func_unique_reward(rm: ReplayMemory, sample: ReplayMemorySample):
    return _weight_func_reward(rm, sample) * _weight_func_unique(rm, sample)

# %% [markdown]
# ## EXPERIMENT

# %%
def _run_experiment(agent, path):
    runner.run_experiment(agent, gym.make(MAZE), EXPLORE_TRIALS, EXPLOIT_TRIALS, path)

def run_acs2_experiment():
    for i in range(REPEAT_START, REPEAT_START + REPEAT):
        # Create agent 
        cfg = CFG_ACS2(    
            classifier_length=8,
            number_of_possible_actions=8,
            metrics_trial_frequency=1,
            user_metrics_collector_fcn=_maze_metrics)
        agent = ACS2(cfg)

        _run_experiment(agent, f'{i}')

def _run_acs2er_experiment(er_samples_number: int):
    for i in range(REPEAT_START, REPEAT_START + REPEAT):
        # Create agent 
        cfg = CFG_ACS2ER(    
            classifier_length=8,
            number_of_possible_actions=8,
            metrics_trial_frequency=1,
            er_buffer_size=ER_BUFFER_SIZE,
            er_min_samples=ER_BUFFER_MIN_SAMPLES,
            er_samples_number=er_samples_number,
            user_metrics_collector_fcn=_maze_metrics)
        agent = ACS2ER(cfg)

        _run_experiment(agent, os.path.join(f'm_3-ER', f'{i}'))

def run_acs2er_experiments():
    for er_samples_number in ER_SAMPLES_NUMBER_LIST:
        print(f"START - ACS2ER - {er_samples_number}")
        _run_acs2er_experiment(er_samples_number)
        print(f"END - ACS2ER - {er_samples_number}")

def _run_acs2per_experiment(er_samples_number: int):
    for i in range(REPEAT_START, REPEAT_START + REPEAT):
        # Create agent 
        cfg = CFG_ACS2ER(    
            classifier_length=8,
            number_of_possible_actions=8,
            metrics_trial_frequency=1,
            er_buffer_size=ER_BUFFER_SIZE,
            er_min_samples=ER_BUFFER_MIN_SAMPLES,
            er_samples_number=er_samples_number,
            er_weight_function=_weight_func_reward,
            user_metrics_collector_fcn=_maze_metrics)
        agent = ACS2ER(cfg)

        _run_experiment(agent, os.path.join(f'm_3-pER_reward', f'{i}'))

def run_acs2per_experiments():
    for er_samples_number in ER_SAMPLES_NUMBER_LIST:
        print(f"START - ACS2pER - reward")
        _run_acs2per_experiment(er_samples_number)
        print(f"END - ACS2pER - reward")


def _run_acs2per2_experiment(er_samples_number: int):
    for i in range(REPEAT_START, REPEAT_START + REPEAT):
        # Create agent 
        cfg = CFG_ACS2ER(    
            classifier_length=8,
            number_of_possible_actions=8,
            metrics_trial_frequency=1,
            er_buffer_size=ER_BUFFER_SIZE,
            er_min_samples=ER_BUFFER_MIN_SAMPLES,
            er_samples_number=er_samples_number,
            er_weight_function=_weight_func_unique,
            user_metrics_collector_fcn=_maze_metrics)
        agent = ACS2ER(cfg)

        _run_experiment(agent, os.path.join(f'm_3-pER_unique', f'{i}'))

def run_acs2per2_experiments():
    for er_samples_number in ER_SAMPLES_NUMBER_LIST:
        print(f"START - ACS2pER - unique")
        _run_acs2per2_experiment(er_samples_number)
        print(f"END - ACS2pER - unique")


def _run_acs2per3_experiment(er_samples_number: int):
    for i in range(REPEAT_START, REPEAT_START + REPEAT):
        # Create agent
        cfg = CFG_ACS2ER(
            classifier_length=8,
            number_of_possible_actions=8,
            metrics_trial_frequency=1,
            er_buffer_size=ER_BUFFER_SIZE,
            er_min_samples=ER_BUFFER_MIN_SAMPLES,
            er_samples_number=er_samples_number,
            er_weight_function=_weight_func_unique_reward,
            user_metrics_collector_fcn=_maze_metrics)
        agent = ACS2ER(cfg)

        _run_experiment(agent, os.path.join(f'm_3-pER_unique_reward', f'{i}'))


def run_acs2per3_experiments():
    for er_samples_number in ER_SAMPLES_NUMBER_LIST:
        print(f"START - ACS2pER - unique + reward")
        _run_acs2per3_experiment(er_samples_number)
        print(f"END - ACS2pER - unique + reward")


def _run_acs2rer_experiment(er_samples_number: int):
    for i in range(REPEAT_START, REPEAT_START + REPEAT):
        # Create agent 
        cfg = CFG_ACS2RER(    
            classifier_length=8,
            number_of_possible_actions=8,
            metrics_trial_frequency=1,
            er_buffer_size=ER_BUFFER_SIZE,
            er_min_samples=ER_BUFFER_MIN_SAMPLES,
            er_samples_number=er_samples_number,
            user_metrics_collector_fcn=_maze_metrics)
        agent = ACS2ER(cfg)

        _run_experiment(agent, os.path.join(f'm_3-RER', f'{i}'))

def run_acs2rer_experiments():
    for er_samples_number in ER_SAMPLES_NUMBER_LIST:
        print(f"START - ACS2ER - {er_samples_number}")
        _run_acs2rer_experiment(er_samples_number)
        print(f"END - ACS2ER - {er_samples_number}")

# %% [markdown]
# ### RUN ACS2 Experiments

# %%
run_acs2_experiment()
# Out:
# INFO:lcs.agents.Agent:{'trial': 20, 'steps_in_trial': 50, 'reward': 0, 'perf_time': 0.41422310000052676, 'knowledge': 3.4246575342465753, 'specificity': 0.5451388888888888, 'optimal': 55.55555555555556, 'optimal_reliable': 5.555555555555555, 'population': 216, 'numerosity': 216, 'reliable': 11}
# INFO:lcs.agents.Agent:{'trial': 40, 'steps_in_trial': 50, 'reward': 0, 'perf_time': 0.4689434000028996, 'knowledge': 6.8493150684931505, 'specificity': 0.5840747330960854, 'optimal': 58.333333333333336, 'optimal_reliable': 8.333333333333332, 'population': 281, 'numerosity': 281, 'reliable': 21}
# INFO:lcs.agents.Agent:{'trial': 60, 'steps_in_trial': 50, 'reward': 0, 'perf_time': 0.4656929999982822, 'knowledge': 14.383561643835616, 'specificity': 0.6152647975077882, 'optimal': 55.55555555555556, 'optimal_reliable': 16.666666666666664, 'population': 321, 'numerosity': 321, 'reliable': 38}
# INFO:lcs.agents.Agent:{'trial': 80, 'steps_in_trial': 4, 'reward': 1000, 'perf_time': 0.039364000000205124, 'knowledge': 17.123287671232877, 'specificity': 0.6212121212121212, 'optimal': 52.77777777777778, 'optimal_reliable': 16.666666666666664, 'population': 330, 'numerosity': 330, 'reliable': 46}
# INFO:lcs.agents.Agent:{'trial': 100, 'steps_in_trial': 17, 'reward': 1000, 'perf_time': 0.14465679999921122, 'knowledge': 22.602739726027394, 'specificity': 0.6227611940298508, 'optimal': 66.66666666666666, 'optimal_reliable': 27.77777777777778, 'population': 335, 'numerosity': 335, 'reliable': 60}
# INFO:lcs.agents.Agent:{'trial': 120, 'steps_in_trial': 14, 'reward': 1000, 'perf_time': 0.1376869000014267, 'knowledge': 28.08219178082192, 'specificity': 0.626453488372093, 'optimal': 69.44444444444444, 'optimal_reliable': 44.44444444444444, 'population': 344, 'numerosity': 344, 'reliable': 70}
# INFO:lcs.agents.Agent:{'trial': 140, 'steps_in_trial': 10, 'reward': 1000, 'perf_time': 0.08744929999738815, 'knowledge': 29.45205479452055, 'specificity': 0.6257062146892656, 'optimal': 52.77777777777778, 'optimal_reliable': 52.77777777777778, 'population': 354, 'numerosity': 354, 'reliable': 74}
# INFO:lcs.agents.Agent:{'trial': 160, 'steps_in_trial': 7, 'reward': 1000, 'perf_time': 0.06272460000036517, 'knowledge': 31.506849315068493, 'specificity': 0.6256925207756233, 'optimal': 52.77777777777778, 'optimal_reliable': 52.77777777777778, 'population': 361, 'numerosity': 361, 'reliable': 82}
# INFO:lcs.agents.Agent:{'trial': 180, 'steps_in_trial': 9, 'reward': 1000, 'perf_time': 0.07933010000124341, 'knowledge': 32.87671232876712, 'specificity': 0.633245382585752, 'optimal': 58.333333333333336, 'optimal_reliable': 52.77777777777778, 'population': 379, 'numerosity': 379, 'reliable': 84}
# INFO:lcs.agents.Agent:{'trial': 200, 'steps_in_trial':
 'knowledge': 47.94520547945205, 'specificity': 0.6554878048780488, 'optimal': 66.66666666666666, 'optimal_reliable': 55.55555555555556, 'population': 492, 'numerosity': 492, 'reliable': 189}
# INFO:lcs.agents.Agent:{'trial': 180, 'steps_in_trial': 5, 'reward': 1000, 'perf_time': 0.0513176000022213, 'knowledge': 47.94520547945205, 'specificity': 0.6554878048780488, 'optimal': 63.888888888888886, 'optimal_reliable': 55.55555555555556, 'population': 492, 'numerosity': 492, 'reliable': 189}
# INFO:lcs.agents.Agent:{'trial': 200, 'steps_in_trial': 6, 'reward': 1000, 'perf_time': 0.07828979999976582, 'knowledge': 47.94520547945205, 'specificity': 0.6554878048780488, 'optimal': 69.44444444444444, 'optimal_reliable': 55.55555555555556, 'population': 492, 'numerosity': 492, 'reliable': 189}
# INFO:lcs.agents.Agent:{'trial': 20, 'steps_in_trial': 50, 'reward': 0, 'perf_time': 0.6023152000016125, 'knowledge': 2.054794520547945, 'specificity': 0.608016304347826, 'optimal': 22.22222222222222, 'optimal_reliable': 2.7777777777777777, 'population': 368, 'numerosity': 368, 'reliable': 12}
# INFO:lcs.agents.Agent:{'trial': 40, 'steps_in_trial': 50, 'reward': 0, 'perf_time': 0.6062385000004724, 'knowledge': 13.013698630136986, 'specificity': 0.640661938534279, 'optimal': 25.0, 'optimal_reliable': 8.333333333333332, 'population': 423, 'numerosity': 423, 'reliable': 49}
# INFO:lcs.agents.Agent:{'trial': 60, 'steps_in_trial': 50, 'reward': 0, 'perf_time': 0.48398140000062995, 'knowledge': 26.027397260273972, 'specificity': 0.6625600961538461, 'optimal': 27.77777777777778, 'optimal_reliable': 11.11111111111111, 'population': 416, 'numerosity': 416, 'reliable': 96}
# INFO:lcs.agents.Agent:{'trial': 80, 'steps_in_trial': 29, 'reward': 1000, 'perf_time': 0.3944024000011268, 'knowledge': 41.78082191780822, 'specificity': 0.6712622549019608, 'optimal': 50.0, 'optimal_reliable': 33.33333333333333, 'population': 408, 'numerosity': 408, 'reliable': 145}
# INFO:lcs.agents.Agent:{'trial': 100, 'steps_in_trial': 50, 'reward': 0, 'perf_time': 0.4744611999994959, 'knowledge': 47.26027397260274, 'specificity': 0.6787084398976982, 'optimal': 44.44444444444444, 'optimal_reliable': 30.555555555555557, 'population': 391, 'numerosity': 391, 'reliable': 171}
# INFO:lcs.agents.Agent:{'trial': 120, 'steps_in_trial': 14, 'reward': 1000, 'perf_time': 0.1070614000018395, 'knowledge': 50.0, 'specificity': 0.6789845758354756, 'optimal': 63.888888888888886, 'optimal_reliable': 44.44444444444444, 'population': 389, 'numerosity': 389, 'reliable': 177}
# INFO:lcs.agents.Agent:{'trial': 140, 'steps_in_trial': 17, 'reward': 1000, 'perf_time': 0.13385160000325413, 'knowledge': 52.73972602739726, 'specificity': 0.6813151041666666, 'optimal': 58.333333333333336, 'optimal_reliable': 52.77777777777778, 'population': 384, 'numerosity': 384, 'reliable': 184}
# INFO:lcs.agents.Agent:{'trial': 160, 'steps_in_trial': 35, 'reward': 1000, 'perf_time': 0.2828892999968957, 'knowledge': 54.794520547945204, 'specificity': 0.6808441558441558, 'optimal': 58.333333333333336, 'optimal_reliable': 52.77777777777778, 'population': 385, 'numerosity': 385, 'reliable': 192}
# INFO:lcs.agents.Agent:{'trial': 180, 'steps_in_trial': 14, 'reward': 1000, 'perf_time': 0.10600780000095256, 'knowledge': 58.21917808219178, 'specificity': 0.681640625, 'optimal': 58.333333333333336, 'optimal_reliable': 55.55555555555556, 'population': 384, 'numerosity': 384, 'reliable': 200}
# INFO:lcs.agents.Agent:{'trial': 200, 'steps_in_trial': 11, 'reward': 1000, 'perf_time': 0.0846393000028911, 'knowledge': 58.9041095890411, 'specificity': 0.6827427821522309, 'optimal': 58.333333333333336, 'optimal_reliable': 58.333333333333336, 'population': 381, 'numerosity': 381, 'reliable': 204}
# INFO:lcs.agents.Agent:{'trial': 20, 'steps_in_trial': 6, 'reward': 1000, 'perf_time': 0.04276980000213371, 'knowledge': 58.9041095890411, 'specificity': 0.6827427821522309, 'optimal': 58.333333333333336, 'optimal_reliable': 58.333333333333336, 'population': 381, 'numerosity': 381, 'reliable': 204}
# INFO:lcs.agents.Agent:{'trial': 40, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.007089499998983229, 'knowledge': 58.9041095890411, 'specificity': 0.6827427821522309, 'optimal': 58.333333333333336, 'optimal_reliable': 58.333333333333336, 'population': 381, 'numerosity': 381, 'reliable': 204}
# INFO:lcs.agents.Agent:{'trial': 60, 'steps_in_trial': 5, 'reward': 1000, 'perf_time': 0.03493460000026971, 'knowledge': 58.9041095890411, 'specificity': 0.6827427821522309, 'optimal': 63.888888888888886, 'optimal_reliable': 58.333333333333336, 'population': 381, 'numerosity': 381, 'reliable': 204}
# INFO:lcs.agents.Agent:{'trial': 80, 'steps_in_trial': 10, 'reward': 1000, 'perf_time': 0.09697150000283727, 'knowledge': 58.9041095890411, 'specificity': 0.6827427821522309, 'optimal': 69.44444444444444, 'optimal_reliable': 58.333333333333336, 'population': 381, 'numerosity': 381, 'reliable': 204}
# INFO:lcs.agents.Agent:{'trial': 100, 'steps_in_trial': 3, 'reward': 1000, 'perf_time': 0.02143620000060764, 'knowledge': 58.9041095890411, 'specificity': 0.6827427821522309, 'optimal': 69.44444444444444, 'optimal_reliable': 58.333333333333336, 'population': 381, 'numerosity': 381, 'reliable': 204}
# INFO:lcs.agents.Agent:{'trial': 120, 'steps_in_trial': 4, 'reward': 1000, 'perf_time': 0.026119499998458195, 'knowledge': 58.9041095890411, 'specificity': 0.6827427821522309, 'optimal': 69.44444444444444, 'optimal_reliable': 58.333333333333336, 'population': 381, 'numerosity': 381, 'reliable': 204}
# INFO:lcs.agents.Agent:{'trial': 140, 'steps_in_trial': 6, 'reward': 1000, 'perf_time': 0.043271499998809304, 'knowledge': 58.9041095890411, 'specificity': 0.6827427821522309, 'optimal': 69.44444444444444, 'optimal_reliable': 58.333333333333336, 'population': 381, 'numerosity': 381, 'reliable': 204}
# INFO:lcs.agents.Agent:{'trial': 160, 'steps_in_trial': 8, 'reward': 1000, 'perf_time': 0.06049239999993006, 'knowledge': 58.9041095890411, 'specificity': 0.6827427821522309, 'optimal': 69.44444444444444, 'optimal_reliable': 61.111111111111114, 'population': 381, 'numerosity': 381, 'reliable': 204}
# INFO:lcs.agents.Agent:{'trial': 180, 'steps_in_trial': 4, 'reward': 1000, 'perf_time': 0.03054839999822434, 'knowledge': 58.9041095890411, 'specificity': 0.6827427821522309, 'optimal': 69.44444444444444, 'optimal_reliable': 61.111111111111114, 'population': 381, 'numerosity': 381, 'reliable': 204}
# INFO:lcs.agents.Agent:{'trial': 200, 'steps_in_trial': 3, 'reward': 1000, 'perf_time': 0.018991700002516154, 'knowledge': 58.9041095890411, 'specificity': 0.6827427821522309, 'optimal': 69.44444444444444, 'optimal_reliable': 61.111111111111114, 'population': 381, 'numerosity': 381, 'reliable': 204}

# %% [markdown]
# ### RUN ACS2ER Experiments

# %%
run_acs2er_experiments()
# Out:
# START - ACS2ER - 3
# INFO:lcs.agents.Agent:{'trial': 20, 'steps_in_trial': 50, 'reward': 0, 'perf_time':

# INFO:lcs.agents.Agent:{'trial': 20, 'steps_in_trial': 14, 'reward': 1000, 'perf_time': 1.244716500001232, 'knowledge': 6.164383561643835, 'specificity': 0.5413647342995169, 'optimal': 47.22222222222222, 'optimal_reliable': 8.333333333333332, 'population': 414, 'numerosity': 414, 'reliable': 38}
# INFO:lcs.agents.Agent:{'trial': 40, 'steps_in_trial': 21, 'reward': 1000, 'perf_time': 1.9433109000019613, 'knowledge': 32.19178082191781, 'specificity': 0.5846518987341772, 'optimal': 44.44444444444444, 'optimal_reliable': 38.88888888888889, 'population': 474, 'numerosity': 474, 'reliable': 112}
# INFO:lcs.agents.Agent:{'trial': 60, 'steps_in_trial': 12, 'reward': 1000, 'perf_time': 1.2277452999987872, 'knowledge': 45.20547945205479, 'specificity': 0.6180952380952381, 'optimal': 50.0, 'optimal_reliable': 41.66666666666667, 'population': 525, 'numerosity': 525, 'reliable': 153}
# INFO:lcs.agents.Agent:{'trial': 80, 'steps_in_trial': 8, 'reward': 1000, 'perf_time': 0.9114986000022327, 'knowledge': 59.589041095890416, 'specificity': 0.6309306569343066, 'optimal': 55.55555555555556, 'optimal_reliable': 52.77777777777778, 'population': 548, 'numerosity': 548, 'reliable': 204}
# INFO:lcs.agents.Agent:{'trial': 100, 'steps_in_trial': 20, 'reward': 1000, 'perf_time': 2.6808258999990358, 'knowledge': 67.12328767123287, 'specificity': 0.6447602131438721, 'optimal': 52.77777777777778, 'optimal_reliable': 52.77777777777778, 'population': 563, 'numerosity': 563, 'reliable': 253}
# INFO:lcs.agents.Agent:{'trial': 120, 'steps_in_trial': 3, 'reward': 1000, 'perf_time': 0.42123589999755495, 'knowledge': 74.65753424657534, 'specificity': 0.6536172161172161, 'optimal': 55.55555555555556, 'optimal_reliable': 58.333333333333336, 'population': 546, 'numerosity': 546, 'reliable': 298}
# INFO:lcs.agents.Agent:{'trial': 140, 'steps_in_trial': 9, 'reward': 1000, 'perf_time': 1.35940760000085, 'knowledge': 80.82191780821918, 'specificity': 0.6583180147058824, 'optimal': 63.888888888888886, 'optimal_reliable': 61.111111111111114, 'population': 544, 'numerosity': 544, 'reliable': 326}
# INFO:lcs.agents.Agent:{'trial': 160, 'steps_in_trial': 12, 'reward': 1000, 'perf_time': 1.8958173999999417, 'knowledge': 86.3013698630137, 'specificity': 0.6620283018867924, 'optimal': 66.66666666666666, 'optimal_reliable': 66.66666666666666, 'population': 530, 'numerosity': 530, 'reliable': 356}
# INFO:lcs.agents.Agent:{'trial': 180, 'steps_in_trial': 12, 'reward': 1000, 'perf_time': 1.9494900999998208, 'knowledge': 88.35616438356165, 'specificity': 0.6640325670498084, 'optimal': 66.66666666666666, 'optimal_reliable': 66.66666666666666, 'population': 522, 'numerosity': 522, 'reliable': 370}
# INFO:lcs.agents.Agent:{'trial': 200, 'steps_in_trial': 11, 'reward': 1000, 'perf_time': 1.994257499998639, 'knowledge': 91.0958904109589, 'specificity': 0.6689723320158103, 'optimal': 69.44444444444444, 'optimal_reliable': 72.22222222222221, 'population': 506, 'numerosity': 506, 'reliable': 391}
# INFO:lcs.agents.Agent:{'trial': 20, 'steps_in_trial': 3, 'reward': 1000, 'perf_time': 0.031853799999225885, 'knowledge': 91.0958904109589, 'specificity': 0.6689723320158103, 'optimal': 69.44444444444444, 'optimal_reliable': 72.22222222222221, 'population': 506, 'numerosity': 506, 'reliable': 391}
# INFO:lcs.agents.Agent:{'trial': 40, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.007336499998928048, 'knowledge': 91.0958904109589, 'specificity': 0.6689723320158103, 'optimal': 69.44444444444444, 'optimal_reliable': 72.22222222222221, 'population': 506, 'numerosity': 506, 'reliable': 391}
# INFO:lcs.agents.Agent:{'trial': 60, 'steps_in_trial': 6, 'reward': 1000, 'perf_time': 0.059082799998577684, 'knowledge': 91.0958904109589, 'specificity': 0.6689723320158103, 'optimal': 69.44444444444444, 'optimal_reliable': 72.22222222222221, 'population': 506, 'numerosity': 506, 'reliable': 391}
# INFO:lcs.agents.Agent:{'trial': 80, 'steps_in_trial': 3, 'reward': 1000, 'perf_time': 0.034135199999582255, 'knowledge': 91.0958904109589, 'specificity': 0.6689723320158103, 'optimal': 72.22222222222221, 'optimal_reliable': 75.0, 'population': 506, 'numerosity': 506, 'reliable': 391}
# INFO:lcs.agents.Agent:{'trial': 100, 'steps_in_trial': 4, 'reward': 1000, 'perf_time': 0.037757199999759905, 'knowledge': 91.0958904109589, 'specificity': 0.6689723320158103, 'optimal': 69.44444444444444, 'optimal_reliable': 72.22222222222221, 'population': 506, 'numerosity': 506, 'reliable': 391}
# INFO:lcs.agents.Agent:{'trial': 120, 'steps_in_trial': 7, 'reward': 1000, 'perf_time': 0.07479550000061863, 'knowledge': 91.0958904109589, 'specificity': 0.6689723320158103, 'optimal': 75.0, 'optimal_reliable': 77.77777777777779, 'population': 506, 'numerosity': 506, 'reliable': 391}
# INFO:lcs.agents.Agent:{'trial': 140, 'steps_in_trial': 4, 'reward': 1000, 'perf_time': 0.03791060000003199, 'knowledge': 91.0958904109589, 'specificity': 0.6689723320158103, 'optimal': 72.22222222222221, 'optimal_reliable': 75.0, 'population': 506, 'numerosity': 506, 'reliable': 391}
# INFO:lcs.agents.Agent:{'trial': 160, 'steps_in_trial': 4, 'reward': 1000, 'perf_time': 0.037854099999094615, 'knowledge': 91.0958904109589, 'specificity': 0.6689723320158103, 'optimal': 75.0, 'optimal_reliable': 77.77777777777779, 'population': 506, 'numerosity': 506, 'reliable': 391}
# INFO:lcs.agents.Agent:{'trial': 180, 'steps_in_trial': 8, 'reward': 1000, 'perf_time': 0.08578190000116592, 'knowledge': 91.0958904109589, 'specificity': 0.6689723320158103, 'optimal': 72.22222222222221, 'optimal_reliable': 75.0, 'population': 506, 'numerosity': 506, 'reliable': 391}
# INFO:lcs.agents.Agent:{'trial': 200, 'steps_in_trial': 5, 'reward': 1000, 'perf_time': 0.050154900000052294, 'knowledge': 91.0958904109589, 'specificity': 0.6689723320158103, 'optimal': 72.22222222222221, 'optimal_reliable': 75.0, 'population': 506, 'numerosity': 506, 'reliable': 391}
# END - ACS2pER - unique

# %%
run_acs2per3_experiments()
# Out:
# START - ACS2pER - unique + reward
# INFO:lcs.agents.Agent:{'trial': 20, 'steps_in_trial': 50, 'reward': 0, 'perf_time': 4.028499699998065, 'knowledge': 21.91780821917808, 'specificity': 0.5944798301486199, 'optimal': 38.88888888888889, 'optimal_reliable': 33.33333333333333, 'population': 471, 'numerosity': 471, 'reliable': 70}
# INFO:lcs.agents.Agent:{'trial': 40, 'steps_in_trial': 50, 'reward': 0, 'perf_time': 5.277778200001194, 'knowledge': 44.52054794520548, 'specificity': 0.63732741617357, 'optimal': 50.0, 'optimal_reliable': 47.22222222222222, 'population': 507, 'numerosity': 507, 'reliable': 149}
# INFO:lcs.agents.Agent:{'trial': 60, 'steps_in_trial': 50, 'reward': 0, 'perf_time':

# INFO:lcs.agents.Agent:{'trial': 160, 'steps_in_trial': 15, 'reward': 1000, 'perf_time': 2.2906537000017124, 'knowledge': 76.71232876712328, 'specificity': 0.6512653374233128, 'optimal': 75.0, 'optimal_reliable': 72.22222222222221, 'population': 652, 'numerosity': 652, 'reliable': 358}
# INFO:lcs.agents.Agent:{'trial': 180, 'steps_in_trial': 10, 'reward': 1000, 'perf_time': 1.9437223999993876, 'knowledge': 80.13698630136986, 'specificity': 0.6555599369085173, 'optimal': 75.0, 'optimal_reliable': 80.55555555555556, 'population': 634, 'numerosity': 634, 'reliable': 397}
# INFO:lcs.agents.Agent:{'trial': 200, 'steps_in_trial': 10, 'reward': 1000, 'perf_time': 1.7262449000008928, 'knowledge': 80.82191780821918, 'specificity': 0.6568979266347688, 'optimal': 75.0, 'optimal_reliable': 77.77777777777779, 'population': 627, 'numerosity': 627, 'reliable': 411}
# INFO:lcs.agents.Agent:{'trial': 20, 'steps_in_trial': 5, 'reward': 1000, 'perf_time': 0.0880267000029562, 'knowledge': 80.82191780821918, 'specificity': 0.6568979266347688, 'optimal': 75.0, 'optimal_reliable': 80.55555555555556, 'population': 627, 'numerosity': 627, 'reliable': 411}
# INFO:lcs.agents.Agent:{'trial': 40, 'steps_in_trial': 4, 'reward': 1000, 'perf_time': 0.05323750000025029, 'knowledge': 80.82191780821918, 'specificity': 0.6568979266347688, 'optimal': 77.77777777777779, 'optimal_reliable': 80.55555555555556, 'population': 627, 'numerosity': 627, 'reliable': 411}
# INFO:lcs.agents.Agent:{'trial': 60, 'steps_in_trial': 2, 'reward': 1000, 'perf_time': 0.023658300000533927, 'knowledge': 80.82191780821918, 'specificity': 0.6568979266347688, 'optimal': 77.77777777777779, 'optimal_reliable': 80.55555555555556, 'population': 627, 'numerosity': 627, 'reliable': 411}
# INFO:lcs.agents.Agent:{'trial': 80, 'steps_in_trial': 5, 'reward': 1000, 'perf_time': 0.06733969999913825, 'knowledge': 80.82191780821918, 'specificity': 0.6568979266347688, 'optimal': 77.77777777777779, 'optimal_reliable': 80.55555555555556, 'population': 627, 'numerosity': 627, 'reliable': 411}
# INFO:lcs.agents.Agent:{'trial': 100, 'steps_in_trial': 4, 'reward': 1000, 'perf_time': 0.05244069999753265, 'knowledge': 80.82191780821918, 'specificity': 0.6568979266347688, 'optimal': 77.77777777777779, 'optimal_reliable': 80.55555555555556, 'population': 627, 'numerosity': 627, 'reliable': 411}
# INFO:lcs.agents.Agent:{'trial': 120, 'steps_in_trial': 2, 'reward': 1000, 'perf_time': 0.02356119999967632, 'knowledge': 80.82191780821918, 'specificity': 0.6568979266347688, 'optimal': 77.77777777777779, 'optimal_reliable': 80.55555555555556, 'population': 627, 'numerosity': 627, 'reliable': 411}
# INFO:lcs.agents.Agent:{'trial': 140, 'steps_in_trial': 5, 'reward': 1000, 'perf_time': 0.0651864999999816, 'knowledge': 80.82191780821918, 'specificity': 0.6568979266347688, 'optimal': 77.77777777777779, 'optimal_reliable': 80.55555555555556, 'population': 627, 'numerosity': 627, 'reliable': 411}
# INFO:lcs.agents.Agent:{'trial': 160, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.009338399999251124, 'knowledge': 80.82191780821918, 'specificity': 0.6568979266347688, 'optimal': 77.77777777777779, 'optimal_reliable': 80.55555555555556, 'population': 627, 'numerosity': 627, 'reliable': 411}
# INFO:lcs.agents.Agent:{'trial': 180, 'steps_in_trial': 4, 'reward': 1000, 'perf_time': 0.050996699999814155, 'knowledge': 80.82191780821918, 'specificity': 0.6568979266347688, 'optimal': 77.77777777777779, 'optimal_reliable': 80.55555555555556, 'population': 627, 'numerosity': 627, 'reliable': 411}
# INFO:lcs.agents.Agent:{'trial': 200, 'steps_in_trial': 3, 'reward': 1000, 'perf_time': 0.03824639999947976, 'knowledge': 80.82191780821918, 'specificity': 0.6568979266347688, 'optimal': 77.77777777777779, 'optimal_reliable': 80.55555555555556, 'population': 627, 'numerosity': 627, 'reliable': 411}
# END - ACS2pER - unique + reward

# %%
run_acs2rer_experiments()
# Out:
# START - ACS2ER - 3
# INFO:lcs.agents.Agent:{'trial': 20, 'steps_in_trial': 6, 'reward': 1000, 'perf_time': 0.3601178999997501, 'knowledge': 26.027397260273972, 'specificity': 0.5807349665924276, 'optimal': 41.66666666666667, 'optimal_reliable': 27.77777777777778, 'population': 449, 'numerosity': 449, 'reliable': 114}
# INFO:lcs.agents.Agent:{'trial': 40, 'steps_in_trial': 43, 'reward': 1000, 'perf_time': 3.2124911999999313, 'knowledge': 41.0958904109589, 'specificity': 0.6257668711656442, 'optimal': 61.111111111111114, 'optimal_reliable': 27.77777777777778, 'population': 489, 'numerosity': 489, 'reliable': 167}
# INFO:lcs.agents.Agent:{'trial': 60, 'steps_in_trial': 15, 'reward': 1000, 'perf_time': 0.8224566999997478, 'knowledge': 47.94520547945205, 'specificity': 0.6361111111111111, 'optimal': 61.111111111111114, 'optimal_reliable': 36.11111111111111, 'population': 495, 'numerosity': 495, 'reliable': 186}
# INFO:lcs.agents.Agent:{'trial': 80, 'steps_in_trial': 8, 'reward': 1000, 'perf_time': 0.44865260000005946, 'knowledge': 52.054794520547944, 'specificity': 0.644155206286837, 'optimal': 69.44444444444444, 'optimal_reliable': 41.66666666666667, 'population': 509, 'numerosity': 509, 'reliable': 199}
# INFO:lcs.agents.Agent:{'trial': 100, 'steps_in_trial': 10, 'reward': 1000, 'perf_time': 0.5649135000021488, 'knowledge': 58.21917808219178, 'specificity': 0.6459153543307087, 'optimal': 66.66666666666666, 'optimal_reliable': 55.55555555555556, 'population': 508, 'numerosity': 508, 'reliable': 220}
# INFO:lcs.agents.Agent:{'trial': 120, 'steps_in_trial': 3, 'reward': 1000, 'perf_time': 0.1605182999992394, 'knowledge': 62.328767123287676, 'specificity': 0.6491617357001972, 'optimal': 63.888888888888886, 'optimal_reliable': 61.111111111111114, 'population': 507, 'numerosity': 507, 'reliable': 243}
# INFO:lcs.agents.Agent:{'trial': 140, 'steps_in_trial': 9, 'reward': 1000, 'perf_time': 0.5157010000002629, 'knowledge': 67.8082191780822, 'specificity': 0.6553784860557769, 'optimal': 72.22222222222221, 'optimal_reliable': 72.22222222222221, 'population': 502, 'numerosity': 502, 'reliable': 262}
# INFO:lcs.agents.Agent:{'trial': 160, 'steps_in_trial': 12, 'reward': 1000, 'perf_time': 0.6477072000016051, 'knowledge': 70.54794520547945, 'specificity': 0.6587221095334685, 'optimal': 80.55555555555556, 'optimal_reliable': 75.0, 'population': 493, 'numerosity': 493, 'reliable': 279}
# INFO:lcs.agents.Agent:{'trial': 180, 'steps_in_trial': 16, 'reward': 1000, 'perf_time': 0.93564730000071, 'knowledge': 79.45205479452055, 'specificity': 0.6612654320987654, 'optimal': 80.55555555555556, 'optimal_reliable': 77.77777777777779, 'population': 486, 'numerosity': 486, 'reliable': 308}
# INFO:lcs.agents.Agent:{'trial': 200, 'steps_in_trial': 17, 'reward': 1000, 'perf_time': 0.8559170000007725, 'knowledge': 82.1917808219178, 'specificity': 0.6614906832298136, 'optimal': 80.55555555555556, 'optimal_reliable': 80.55555555555556, 'population': 483, 'numerosity': 483, 'reliable': 321}
# INFO:lcs.agents.Agent:{'trial': 20, 'steps_in_trial': 4, 'reward': 1000, 'perf_time': 0.03348779999942053, 'knowledge': 82.1917808219178, 'specificity': 0.6614906832298136, 'optimal': 80.55555555555556, 'optimal_reliable': 80.55555555555556, 'population': 483, 'numerosity': 483, 'reliable': 321}
# INFO:lcs.agents.Agent:{'trial': 40, 'steps_in_trial': 4, 'reward': 1000, 'perf_time': 0.0343923000000359, 'knowledge': 82.1917808219178, 'specificity': 0.6614906832298136, 'optimal': 83.33333333333334, 'optimal_reliable': 80.55555555555556, 'population': 483, 'numerosity': 483, 'reliable': 321}
# INFO:lcs.agents.Agent:{'trial': 60, 'steps_in_trial': 3, 'reward': 1000, 'perf_time': 0.024856700001691934, 'knowledge': 82.1917808219178, 'specificity': 0.6614906832298136, 'optimal': 83.33333333333334, 'optimal_reliable': 80.55555555555556, 'population': 483, 'numerosity': 483, 'reliable': 321}
# INFO:lcs.agents.Agent:{'trial': 80, 'steps_in_trial': 7, 'reward': 1000, 'perf_time': 0.06341199999951641, 'knowledge': 82.1917808219178, 'specificity': 0.6614906832298136, 'optimal': 83.33333333333334, 'optimal_reliable': 80.55555555555556, 'population': 483, 'numerosity': 483, 'reliable': 321}
# INFO:lcs.agents.Agent:{'trial': 100, 'steps_in_trial': 6, 'reward': 1000, 'perf_time': 0.06442100000276696, 'knowledge': 82.1917808219178, 'specificity': 0.6614906832298136, 'optimal': 86.11111111111111, 'optimal_reliable': 80.55555555555556, 'population': 483, 'numerosity': 483, 'reliable': 321}
# INFO:lcs.agents.Agent:{'trial': 120, 'steps_in_trial': 3, 'reward': 1000, 'perf_time': 0.026743599999463186, 'knowledge': 82.1917808219178, 'specificity': 0.6614906832298136, 'optimal': 86.11111111111111, 'optimal_reliable': 83.33333333333334, 'population': 483, 'numerosity': 483, 'reliable': 321}
# INFO:lcs.agents.Agent:{'trial': 140, 'steps_in_trial': 9, 'reward': 1000, 'perf_time': 0.10305789999983972, 'knowledge': 82.1917808219178, 'specificity': 0.6614906832298136, 'optimal': 86.11111111111111, 'optimal_reliable': 83.33333333333334, 'population': 483, 'numerosity': 483, 'reliable': 321}
# INFO:lcs.agents.Agent:{'trial': 160, 'steps_in_trial': 5, 'reward': 1000, 'perf_time': 0.043396999997639796, 'knowledge': 82.1917808219178, 'specificity': 0.6614906832298136, 'optimal': 86.11111111111111, 'optimal_reliable': 83.33333333333334, 'population': 483, 'numerosity': 483, 'reliable': 321}
# INFO:lcs.agents.Agent:{'trial': 180, 'steps_in_trial': 6, 'reward': 1000, 'perf_time': 0.054996099999698345, 'knowledge': 82.1917808219178, 'specificity': 0.6614906832298136, 'optimal': 86.11111111111111, 'optimal_reliable': 83.33333333333334, 'population': 483, 'numerosity': 483, 'reliable': 321}
# INFO:lcs.agents.Agent:{'trial': 200, 'steps_in_trial': 5, 'reward': 1000, 'perf_time': 0.04704229999697418, 'knowledge': 82.1917808219178, 'specificity': 0.6614906832298136, 'optimal': 86.11111111111111, 'optimal_reliable': 83.33333333333334, 'population': 483, 'numerosity': 483, 'reliable': 321}
# INFO:lcs.agents.Agent:{'trial': 20, 'steps_in_trial': 2, 'reward': 1000, 'perf_time': 0.14380309999978635, 'knowledge': 19.17808219178082, 'specificity': 0.5659871244635193, 'optimal': 47.22222222222222, 'optimal_reliable': 27.77777777777778, 'population': 466, 'numerosity': 466, 'reliable': 86}
# INFO:lcs.agents.Agent:{'trial': 40, 'steps_in_trial': 13, 'reward': 1000, 'perf_time': 0.8484823999970104, 'knowledge': 34.93150684931507, 'specificity': 0.6082347140039448, 'optimal': 55.55555555555556, 'optimal_reliable': 36.11111111111111, 'population': 507, 'numerosity': 507, 'reliable': 130}
# INFO:lcs.agents.Agent:{'trial': 60, 'steps_in_trial': 19, 'reward': 1000, 'perf_time': 1.1842518000012205, 'knowledge': 44.52054794520548, 'specificity': 0.6310562015503876, 'optimal': 63.888888888888886, 'optimal_reliable': 41.66666666666667, 'population': 516, 'numerosity': 516, 'reliable': 175}
# INFO:lcs.agents.Agent:{'trial': 80, 'steps_in_trial': 5, 'reward': 1000, 'perf_time': 0.30431839999801014, 'knowledge': 50.0, 'specificity': 0.6446360153256705, 'optimal': 63.888888888888886, 'optimal_reliable': 47.22222222222222, 'population': 522, 'numerosity': 522, 'reliable': 191}
# INFO:lcs.agents.Agent:{'trial': 100, 'steps_in_trial': 4, 'reward': 1000, 'perf_time': 0.23787179999999353, 'knowledge': 56.849315068493155, 'specificity': 0.6486030828516378, 'optimal': 66.66666666666666, 'optimal_reliable': 61.111111111111114, 'population': 519, 'numerosity': 519, 'reliable': 213}
# INFO:lcs.agents.Agent:{'trial': 120, 'steps_in_trial': 11, 'reward': 1000, 'perf_time': 0.5923094999998284, 'knowledge': 58.9041095890411, 'specificity': 0.656496062992126, 'optimal': 72.22222222222221, 'optimal_reliable': 66.66666666666666, 'population': 508, 'numerosity': 508, 'reliable': 232}
# INFO:lcs.agents.Agent:{'trial': 140, 'steps_in_trial': 11, 'reward': 1000, 'perf_time': 0.6162575000016659, 'knowledge': 60.95890410958904, 'specificity': 0.6586345381526104, 'optimal': 75.0, 'optimal_reliable': 69.44444444444444, 'population': 498, 'numerosity': 498, 'reliable': 241}
# INFO:lcs.agents.Agent:{'trial': 160, 'steps_in_trial': 9, 'reward': 1000, 'perf_time': 0.47399379999842495, 'knowledge': 63.6986301369863, 'specificity': 0.6610772357723578, 'optimal': 75.0, 'optimal_reliable': 69.44444444444444, 'population': 492, 'numerosity': 492, 'reliable': 258}
# INFO:lcs.agents.Agent:{'trial': 180, 'steps_in_trial': 11, 'reward': 1000, 'perf_time': 0.5813949000003049, 'knowledge': 68.4931506849315, 'specificity': 0.6630658436213992, 'optimal': 72.22222222222221, 'optimal_reliable': 69.44444444444444, 'population': 486, 'numerosity': 486, 'reliable': 271}
# INFO:lcs.agents.Agent:{'trial': 200, 'steps_in_trial': 20, 'reward': 1000, 'perf_time': 1.0363513000011153, 'knowledge': 69.86301369863014, 'specificity': 0.6677083333333333, 'optimal': 75.0, 'optimal_reliable': 69.44444444444444, 'population': 480, 'numerosity': 480, 'reliable': 278}
# INFO:lcs.agents.Agent:{'trial': 20, 'steps_in_trial': 6, 'reward': 1000, 'perf_time': 0.0636850000009872, 'knowledge': 69.86301369863014, 'specificity': 0.6677083333333333, 'optimal': 75.0, 'optimal_reliable': 69.44444444444444, 'population': 480, 'numerosity': 480, 'reliable': 278}
# INFO:lcs.agents.Agent:{'trial': 40, 'steps_in_trial': 6, 'reward': 1000, 'perf_time': 0.05769710000095074, 'knowledge': 69.86301369863014, 'specificity': 0.6677083333333333, 'optimal': 75.0, 'optimal_reliable': 69.44444444444444, 'population': 480, 'numerosity': 480, 'reliable': 278}
# INFO:lcs.agents.Agent:{'trial': 60, 'steps_in_trial': 7, 'reward': 1000, 'perf_time': 0.08127830000012182, 'knowledge': 69.86301369863014, 'specificity': 0.6677083333333333, 'optimal': 75.0, 'optimal_reliable': 69.44444444444444, 'population': 480, 'numerosity': 480, 'reliable': 278}
# INFO:lcs.agents.Agent:{'trial': 80, 'steps_in_trial': 4, 'reward': 1000, 'perf_time': 0.03371990000232472, 'knowledge': 69.86301369863014, 'specificity': 0.6677083333333333, 'optimal': 75.0, 'optimal_reliable': 69.44444444444444, 'population': 480, 'numerosity': 480, 'reliable': 278}
# INFO:lcs.agents.Agent:{'trial': 100, 'steps_in_trial': 9, 'reward': 1000, 'perf_time': 0.09983709999869461, 'knowledge': 69.86301369863014, 'specificity': 0.6677083333333333, 'optimal': 75.0, 'optimal_reliable': 69.44444444444444, 'population': 480, 'numerosity': 480, 'reliable': 278}
# INFO:lcs.agents.Agent:{'trial': 120, 'steps_in_trial': 2, 'reward': 1000, 'perf_time': 0.015383400001155678, 'knowledge': 69.86301369863014, 'specificity': 0.6677083333333333, 'optimal': 75.0, 'optimal_reliable': 69.44444444444444, 'population': 480, 'numerosity': 480, 'reliable': 278}
# INFO:lcs.agents.Agent:{'trial': 140, 'steps_in_trial': 9, 'reward': 1000, 'perf_time': 0.09181970000281581, 'knowledge': 69.86301369863014, 'specificity': 0.6677083333333333, 'optimal': 75.0, 'optimal_reliable': 69.44444444444444, 'population': 480, 'numerosity': 480, 'reliable': 278}
# INFO:lcs.agents.Agent:{'trial': 160, 'steps_in_trial': 9, 'reward': 1000, 'perf_time': 0.09257969999816851, 'knowledge': 69.86301369863014, 'specificity': 0.6677083333333333, 'optimal': 75.0, 'optimal_reliable': 69.44444444444444, 'population': 480, 'numerosity': 480, 'reliable': 278}
# INFO:lcs.agents.Agent:{'trial': 180, 'steps_in_trial': 3, 'reward': 1000, 'perf_time': 0.027795699999842327, 'knowledge': 69.86301369863014, 'specificity': 0.6677083333333333, 'optimal': 75.0, 'optimal_reliable': 69.44444444444444, 'population': 480, 'numerosity': 480, 'reliable': 278}
# INFO:lcs.agents.Agent:{'trial': 200, 'steps_in_trial': 7, 'reward': 1000, 'perf_time': 0.06952250000176718, 'knowledge': 69.86301369863014, 'specificity': 0.6677083333333333, 'optimal': 75.0, 'optimal_reliable': 69.44444444444444, 'population': 480, 'numerosity': 480, 'reliable': 278}
# INFO:lcs.agents.Agent:{'trial': 20, 'steps_in_trial': 14, 'reward': 1000, 'perf_time': 0.7753687999975227, 'knowledge': 13.698630136986301, 'specificity': 0.5700757575757576, 'optimal': 44.44444444444444, 'optimal_reliable': 22.22222222222222, 'population': 396, 'numerosity': 396, 'reliable': 55}
# INFO:lcs.agents.Agent:{'trial': 40, 'steps_in_trial': 20, 'reward': 1000, 'perf_time': 1.117012099999556, 'knowledge': 32.19178082191781, 'specificity': 0.6185483870967742, 'optimal': 63.888888888888886, 'optimal_reliable': 50.0, 'population': 465, 'numerosity': 465, 'reliable': 124}
# INFO:lcs.agents.Agent:{'trial': 60, 'steps_in_trial': 41, 'reward': 1000, 'perf_time': 2.2631247000026633, 'knowledge': 47.94520547945205, 'specificity': 0.6398870636550308, 'optimal': 58.333333333333336, 'optimal_reliable': 52.77777777777778, 'population': 487, 'numerosity': 487, 'reliable': 176}
# INFO:lcs.agents.Agent:{'trial': 80, 'steps_in_trial': 12, 'reward': 1000, 'perf_time': 0.6586423000007926, 'knowledge': 52.73972602739726, 'specificity': 0.6535931174089069, 'optimal': 63.888888888888886, 'optimal_reliable': 58.333333333333336, 'population': 494, 'numerosity': 494, 'reliable': 208}
# INFO:lcs.agents.Agent:{'trial': 100, 'steps_in_trial': 9, 'reward': 1000, 'perf_time': 0.5197387999978673, 'knowledge': 56.849315068493155, 'specificity': 0.6576305220883534, 'optimal': 69.44444444444444, 'optimal_reliable': 63.888888888888886, 'population': 498, 'numerosity': 498, 'reliable': 226}
# INFO:lcs.agents.Agent:{'trial': 120, 'steps_in_trial': 3, 'reward': 1000, 'perf_time': 0.14957810000123573, 'knowledge': 60.95890410958904, 'specificity': 0.6621413934426229, 'optimal': 69.44444444444444, 'optimal_reliable': 66.66666666666666, 'population': 488, 'numerosity': 488, 'reliable': 246}
# INFO:lcs.agents.Agent:{'trial': 140, 'steps_in_trial': 4, 'reward': 1000, 'perf_time': 0.20722849999947357, 'knowledge': 63.013698630136986, 'specificity': 0.6643518518518519, 'optimal': 75.0, 'optimal_reliable': 66.66666666666666, 'population': 486, 'numerosity': 486, 'reliable': 258}
# INFO:lcs.agents.Agent:{'trial': 160, 'steps_in_trial': 30, 'reward': 1000, 'perf_time': 1.4962794999992184, 'knowledge': 67.12328767123287, 'specificity': 0.6670997920997921, 'optimal': 72.22222222222221, 'optimal_reliable': 66.66666666666666, 'population': 481, 'numerosity': 481, 'reliable': 274}
# INFO:lcs.agents.Agent:{'trial': 180, 'steps_in_trial': 8, 'reward': 1000, 'perf_time': 0.39912639999965904, 'knowledge': 67.8082191780822, 'specificity': 0.6705263157894736, 'optimal': 75.0, 'optimal_reliable': 69.44444444444444, 'population': 475, 'numerosity': 475, 'reliable': 283}
# INFO:lcs.agents.Agent:{'trial': 200, 'steps_in_trial': 17, 'reward': 1000, 'perf_time': 0.8364565000010771, 'knowledge': 71.91780821917808, 'specificity': 0.6721398305084746, 'optimal': 75.0, 'optimal_reliable': 69.44444444444444, 'population': 472, 'numerosity': 472, 'reliable': 295}
# INFO:lcs.agents.Agent:{'trial': 20, 'steps_in_trial': 3, 'reward': 1000, 'perf_time': 0.026485499998671003, 'knowledge': 71.91780821917808, 'specificity': 0.6721398305084746, 'optimal': 77.77777777777779, 'optimal_reliable': 72.22222222222221, 'population': 472, 'numerosity': 472, 'reliable': 295}
# INFO:lcs.agents.Agent:{'trial': 40, 'steps_in_trial': 6, 'reward': 1000, 'perf_time': 0.05826270000034128, 'knowledge': 71.91780821917808, 'specificity': 0.6721398305084746, 'optimal': 75.0, 'optimal_reliable': 72.22222222222221, 'population': 472, 'numerosity': 472, 'reliable': 295}
# INFO:lcs.agents.Agent:{'trial': 60, 'steps_in_trial': 6, 'reward': 1000, 'perf_time': 0.058954199997970136, 'knowledge': 71.91780821917808, 'specificity': 0.6721398305084746, 'optimal': 75.0, 'optimal_reliable': 72.22222222222221, 'population': 472, 'numerosity': 472, 'reliable': 295}
# INFO:lcs.agents.Agent:{'trial': 80, 'steps_in_trial': 7, 'reward': 1000, 'perf_time': 0.06143609999708133, 'knowledge': 71.91780821917808, 'specificity': 0.6721398305084746, 'optimal': 75.0, 'optimal_reliable': 72.22222222222221, 'population': 472, 'numerosity': 472, 'reliable': 295}
# INFO:lcs.agents.Agent:{'trial': 100, 'steps_in_trial': 3, 'reward': 1000, 'perf_time': 0.02450709999902756, 'knowledge': 71.91780821917808, 'specificity': 0.6721398305084746, 'optimal': 77.77777777777779, 'optimal_reliable': 72.22222222222221, 'population': 472, 'numerosity': 472, 'reliable': 295}
# INFO:lcs.agents.Agent:{'trial': 120, 'steps_in_trial': 9, 'reward': 1000, 'perf_time': 0.08662029999686638, 'knowledge': 71.91780821917808, 'specificity': 0.6721398305084746, 'optimal': 77.77777777777779, 'optimal_reliable': 72.22222222222221, 'population': 472, 'numerosity': 472, 'reliable': 295}
# INFO:lcs.agents.Agent:{'trial': 140, 'steps_in_trial': 4, 'reward': 1000, 'perf_time': 0.03164159999869298, 'knowledge': 71.91780821917808, 'specificity': 0.6721398305084746, 'optimal': 75.0, 'optimal_reliable': 72.22222222222221, 'population': 472, 'numerosity': 472, 'reliable': 295}
# INFO:lcs.agents.Agent:{'trial': 160, 'steps_in_trial': 4, 'reward': 1000, 'perf_time': 0.03989509999883012, 'knowledge': 71.91780821917808, 'specificity': 0.6721398305084746, 'optimal': 75.0, 'optimal_reliable': 72.22222222222221, 'population': 472, 'numerosity': 472, 'reliable': 295}
# INFO:lcs.agents.Agent:{'trial': 180, 'steps_in_trial': 3, 'reward': 1000, 'perf_time': 0.026074299999891082, 'knowledge': 71.91780821917808, 'specificity': 0.6721398305084746, 'optimal': 75.0, 'optimal_reliable': 72.22222222222221, 'population': 472, 'numerosity': 472, 'reliable': 295}
# INFO:lcs.agents.Agent:{'trial': 200, 'steps_in_trial': 6, 'reward': 1000, 'perf_time': 0.05971470000076806, 'knowledge': 71.91780821917808, 'specificity': 0.6721398305084746, 'optimal': 75.0, 'optimal_reliable': 72.22222222222221, 'population': 472, 'numerosity': 472, 'reliable': 295}
# END - ACS2ER - 3
