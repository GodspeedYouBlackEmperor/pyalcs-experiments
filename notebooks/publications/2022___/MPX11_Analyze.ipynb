# %%
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

import utils.analyze_load_utils
import utils.analyze_utils

import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

import importlib

# %% [markdown]
# # EXPERIMENT CONFIGURATION

# %%
BASE = 'MPX'
ENV = f'boolean-multiplexer-{11}bit-v0'
FRIENDLY_ENV = 'Multiplexer 11-bit'
ER_SAMPLES_NUMBER_LIST = ['3-ER', '3-pER_reward', '3-pER_unique']
EXPERIMENT_NAME = "MPX11_TEST2"

# %%
importlib.reload(utils.analyze_load_utils)
loader = utils.analyze_load_utils.Loader(BASE, EXPERIMENT_NAME, ENV, M = ER_SAMPLES_NUMBER_LIST)
acs2_data, acs2er_data, acs2_data_full, acs2er_data_full = loader.load()

# %%
importlib.reload(utils.analyze_utils)
config = utils.analyze_utils.AnalyzerConfiguration(
  BASE_NAME=BASE, 
  EXP_NAME=EXPERIMENT_NAME,
  ENV_NAME=ENV,
  FRIENDLY_ENV_NAME=FRIENDLY_ENV,
  M=ER_SAMPLES_NUMBER_LIST,
  DATA_BASE_PATH=BASE)
analyzer = utils.analyze_utils.Analyzer(acs2_data, acs2er_data, config, acs2_data_full, acs2er_data_full)

# %%
analyzer.plot_knowledge(exploit_avg_win=50, explore_avg_win=50, width=0.5)
analyzer.plot_reward(exploit_avg_win=50, explore_avg_win=50, width=0.5)
analyzer.plot_specificity(exploit_avg_win=10, explore_avg_win=10, width=0.5)
analyzer.plot_classifiers(width=0.5)

# %%
analyzer.compare_reward_average_welch_test()
analyzer.compare_reward_exploit_average_welch_test()
# Out:
#                         ACS2-ER m--1        ACS2-ER m-3-ER       ACS2-ER m-3-pER_reward    ACS2-ER m-3-pER_unique
# ----------------------  ------------------  -------------------  ------------------------  ------------------------
# ACS2-ER m--1            s: 0.0, p: 1.0      s: -2.186, p: 0.042  s: -0.22, p: 0.828        s: -3.155, p: 0.005
# ACS2-ER m-3-ER          s: 2.186, p: 0.042  s: 0.0, p: 1.0       s: 1.966, p: 0.065        s: -0.078, p: 0.938
# ACS2-ER m-3-pER_reward  s: 0.22, p: 0.828   s: -1.966, p: 0.065  s: 0.0, p: 1.0            s: -2.817, p: 0.011
# ACS2-ER m-3-pER_unique  s: 3.155, p: 0.005  s: 0.078, p: 0.938   s: 2.817, p: 0.011        s: 0.0, p: 1.0
#                         ACS2-ER m--1         ACS2-ER m-3-ER       ACS2-ER m-3-pER_reward    ACS2-ER m-3-pER_unique
# ----------------------  -------------------  -------------------  ------------------------  ------------------------
# ACS2-ER m--1            s: 0.0, p: 1.0       s: -2.077, p: 0.052  s: 1.111, p: 0.281        s: -1.659, p: 0.114
# ACS2-ER m-3-ER          s: 2.077, p: 0.052   s: 0.0, p: 1.0       s: 4.478, p: 0.0          s: 0.403, p: 0.692
# ACS2-ER m-3-pER_reward  s: -1.111, p: 0.281  s: -4.478, p: 0.0    s: 0.0, p: 1.0            s: -3.582, p: 0.002
# ACS2-ER m-3-pER_unique  s: 1.659, p: 0.114   s: -0.403, p: 0.692  s: 3.582, p: 0.002        s: 0.0, p: 1.0
