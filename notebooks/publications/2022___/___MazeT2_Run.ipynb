# %%
import os
from collections import defaultdict
from utils.run_utils import Runner

import gym
import gym_maze

from lcs.agents import Agent
from lcs.agents.acs2 import ACS2, Configuration as CFG_ACS2, ClassifiersList
from lcs.agents.acs2er import ACS2ER, Configuration as CFG_ACS2ER, ReplayMemory, ReplayMemorySample
from lcs.agents.acs2eer import ACS2EER, Configuration as CFG_ACS2EER, TrialReplayMemory
from lcs.metrics import population_metrics

# Logger
import logging
logging.basicConfig(level=logging.INFO)

# %% [markdown]
# # EXPERIMENT CONFIGURATION

# %%
MAZE = "MazeT2-v0" 
EXPLORE_EXPLOIT_TRIALS = 10000

# The size of ER replay memory buffer
ER_BUFFER_SIZE = 10000
# The minimum number of samples of ER replay memory buffer to start replying samples (warm-up phase)
ER_BUFFER_MIN_SAMPLES = 1000
# The number of samples to be replayed druing ER phase
ER_SAMPLES_NUMBER_LIST = [3]

EER_BUFFER_SIZE = 1000
EER_BUFFER_MIN_SAMPLES = 25


#######

REPEAT_START = 1
REPEAT = 10

EXPERIMENT_NAME = "MAZE_T2_EXP_1" # Please edit if running new experiment to do not override saved results.

# %%
runner = Runner('MAZE', EXPERIMENT_NAME, MAZE)

# %% [markdown]
# ## METRICS

# %%
MAZE_PATH = 0
MAZE_REWARD = 9

optimal_paths_env = gym.make(MAZE)
matrix = optimal_paths_env.matrix
X = matrix.shape[1]
Y = matrix.shape[0]

def get_reward_pos():
    for i in range(Y):
        for j in range(X):
            if(matrix[i, j] == MAZE_REWARD):
                return(i, j)

def get_possible_neighbour_cords(pos_y, pos_x):
    n = ((pos_y - 1, pos_x), 4)
    ne = ((pos_y - 1, pos_x + 1), 5)
    e = ((pos_y, pos_x + 1), 6)
    se = ((pos_y + 1, pos_x + 1), 7)
    s = ((pos_y + 1, pos_x), 0)
    sw = ((pos_y + 1, pos_x - 1), 1)
    w = ((pos_y, pos_x - 1), 2)
    nw = ((pos_y - 1, pos_x - 1), 3)

    return [n, ne, e, se, s, sw, w, nw]

    
optimal_actions = []

root_node = get_reward_pos()

def is_included(cords, level):
    return any(op_cords[0] == cords[0] and op_cords[1] == cords[1] and level != op_level for op_cords, _, op_level in optimal_actions)


def get_optimal_actions_to(node, level):
    neighbour_cords = get_possible_neighbour_cords(node[0], node[1])

    next_level_cords = []
    for (pos_y, pos_x), action in neighbour_cords:
        if (not is_included((pos_y, pos_x), level)) and matrix[pos_y, pos_x] == MAZE_PATH:
            optimal_actions.append(((pos_y, pos_x), action, level))
            next_level_cords.append((pos_y, pos_x))

    return next_level_cords

LEVEL = 0
next_level_cords = get_optimal_actions_to(root_node, LEVEL)

while len(next_level_cords) > 0:
    LEVEL += 1
    new_next_level_cords = []
    for nlc in next_level_cords:
        new_next_level_cords += get_optimal_actions_to(nlc, LEVEL)

    next_level_cords = new_next_level_cords

positions_actions = defaultdict(set)
for cords, a, _ in optimal_actions: positions_actions[cords].add(a)

positions_actions = positions_actions.items()
POSITIONS_OPTIMAL_ACTIONS = list(map(lambda pa: (optimal_paths_env.env.maze.perception(pa[0]), list(pa[1])), positions_actions))
POSITIONS_OPTIMAL_ACTIONS_LENGTH = len(POSITIONS_OPTIMAL_ACTIONS)



def _maze_optimal(classifiers) -> float:
    nr_correct = 0

    for p0, optimal_actions_list in POSITIONS_OPTIMAL_ACTIONS:
        match_set = classifiers.form_match_set(p0)
        cl = match_set.get_best_classifier()

        if cl is not None and optimal_actions_list.count(cl.action) > 0:
            nr_correct += 1

    return nr_correct / POSITIONS_OPTIMAL_ACTIONS_LENGTH * 100.0


def _maze_optimal_reliable(classifiers) -> float:
    return _maze_optimal(ClassifiersList(*[c for c in classifiers if c.is_reliable()]))

# %%
def _get_transitions():
    knowledge_env = gym.make(MAZE)
    transitions = knowledge_env.env.get_transitions()
    transitions = list(map(lambda t: [knowledge_env.env.maze.perception(t[0]), t[1], knowledge_env.env.maze.perception(t[2])], transitions))

    return transitions

TRANSITIONS = _get_transitions()
TRANSITIONS_LENGTH = len(TRANSITIONS)

def _maze_knowledge(population) -> float:
    # Take into consideration only reliable classifiers
    reliable_classifiers = [c for c in population if c.is_reliable()]

    # Count how many transitions are anticipated correctly
    nr_correct = 0

    # For all possible destinations from each path cell
    for p0, action, p1 in TRANSITIONS:
        if any([True for cl in reliable_classifiers
                if cl.predicts_successfully(p0, action, p1)]):
            nr_correct += 1

    return nr_correct / TRANSITIONS_LENGTH * 100.0

def _maze_specificity(population) -> float:
    pop_len = len(population)
    if(pop_len) == 0:
        return 0
    return sum(map(lambda c: c.specificity, population)) / pop_len

def _maze_metrics(agent, env):
    pop = agent.population
    metrics = {
        'knowledge': _maze_knowledge(pop),
        "specificity": _maze_specificity(agent.population),
        "optimal": _maze_optimal(agent.population),
        "optimal_reliable": _maze_optimal_reliable(agent.population)
    }
    metrics.update(population_metrics(pop, env))
    
    return metrics

# %% [markdown]
# ## EXPERIMENT

# %%
def _run_experiment(agent, path):
    runner.run_experiment_explore_exploit(agent, gym.make(MAZE), EXPLORE_EXPLOIT_TRIALS, path)

def run_acs2_experiment():
    for i in range(REPEAT_START, REPEAT_START + REPEAT):
        # Create agent 
        cfg = CFG_ACS2(    
            classifier_length=8,
            number_of_possible_actions=8,
            metrics_trial_frequency=1,
            user_metrics_collector_fcn=_maze_metrics)
        agent = ACS2(cfg)

        _run_experiment(agent, f'{i}')

def _run_acs2er_experiment(er_samples_number: int):
    for i in range(REPEAT_START, REPEAT_START + REPEAT):
        # Create agent 
        cfg = CFG_ACS2ER(    
            classifier_length=8,
            number_of_possible_actions=8,
            metrics_trial_frequency=1,
            er_buffer_size=ER_BUFFER_SIZE,
            er_min_samples=ER_BUFFER_MIN_SAMPLES,
            er_samples_number=er_samples_number,
            user_metrics_collector_fcn=_maze_metrics)
        agent = ACS2ER(cfg)

        _run_experiment(agent, os.path.join(f'm_3-ER', f'{i}'))

def run_acs2er_experiments():
    for er_samples_number in ER_SAMPLES_NUMBER_LIST:
        print(f"START - ACS2ER - {er_samples_number}")
        _run_acs2er_experiment(er_samples_number)
        print(f"END - ACS2ER - {er_samples_number}")


def _run_acs2eer_experiment(er_samples_number: int):
    for i in range(REPEAT_START, REPEAT_START + REPEAT):
        # Create agent 
        cfg = CFG_ACS2EER(           
            classifier_length=8,
            number_of_possible_actions=8,
            metrics_trial_frequency=1,
            er_buffer_size=EER_BUFFER_SIZE,
            er_min_samples=int(EER_BUFFER_MIN_SAMPLES),
            er_samples_number=er_samples_number,
            user_metrics_collector_fcn=_maze_metrics)
        agent = ACS2EER(cfg)

        _run_experiment(agent, os.path.join(f'm_3-EER', f'{i}'))

def run_acs2eer_experiments():
    for er_samples_number in ER_SAMPLES_NUMBER_LIST:
        print(f"START - ACS2EER - {er_samples_number}")
        _run_acs2eer_experiment(er_samples_number)
        print(f"END - ACS2EER - {er_samples_number}")

# %% [markdown]
# ### RUN ACS2 Experiments

# %%
run_acs2_experiment()
# Out:
# INFO:lcs.agents.Agent:{'trial': 30, 'steps_in_trial': 7, 'reward': 1000, 'perf_time': 0.003649700000000422, 'knowledge': 0.0, 'specificity': 0.2857142857142857, 'optimal': 100.0, 'optimal_reliable': 0.0, 'population': 21, 'numerosity': 21, 'reliable': 0}
# INFO:lcs.agents.Agent:{'trial': 60, 'steps_in_trial': 2, 'reward': 1000, 'perf_time': 0.0014625000000005883, 'knowledge': 0.0, 'specificity': 0.25, 'optimal': 100.0, 'optimal_reliable': 0.0, 'population': 34, 'numerosity': 34, 'reliable': 0}
# INFO:lcs.agents.Agent:{'trial': 90, 'steps_in_trial': 6, 'reward': 1000, 'perf_time': 0.005407999999999191, 'knowledge': 21.428571428571427, 'specificity': 0.225, 'optimal': 100.0, 'optimal_reliable': 60.0, 'population': 45, 'numerosity': 45, 'reliable': 3}
# INFO:lcs.agents.Agent:{'trial': 120, 'steps_in_trial': 3, 'reward': 1000, 'perf_time': 0.0041045000000003995, 'knowledge': 21.428571428571427, 'specificity': 0.2222222222222222, 'optimal': 100.0, 'optimal_reliable': 60.0, 'population': 54, 'numerosity': 54, 'reliable': 3}
# INFO:lcs.agents.Agent:{'trial': 150, 'steps_in_trial': 5, 'reward': 1000, 'perf_time': 0
 'reliable': 1}
# INFO:lcs.agents.Agent:{'trial': 60, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.0007595000000009122, 'knowledge': 35.714285714285715, 'specificity': 0.2326388888888889, 'optimal': 80.0, 'optimal_reliable': 60.0, 'population': 36, 'numerosity': 36, 'reliable': 5}
# INFO:lcs.agents.Agent:{'trial': 90, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.0016153000000009854, 'knowledge': 35.714285714285715, 'specificity': 0.25707547169811323, 'optimal': 80.0, 'optimal_reliable': 60.0, 'population': 53, 'numerosity': 53, 'reliable': 5}
# INFO:lcs.agents.Agent:{'trial': 120, 'steps_in_trial': 7, 'reward': 1000, 'perf_time': 0.01631709999999842, 'knowledge': 35.714285714285715, 'specificity': 0.2520833333333333, 'optimal': 80.0, 'optimal_reliable': 60.0, 'population': 60, 'numerosity': 60, 'reliable': 5}
# INFO:lcs.agents.Agent:{'trial': 150, 'steps_in_trial': 7, 'reward': 1000, 'perf_time': 0.021159600000000722, 'knowledge': 42.857142857142854, 'specificity': 0.24305555555555555, 'optimal': 80.0, 'optimal_reliable': 60.0, 'population': 72, 'numerosity': 72, 'reliable': 7}
# INFO:lcs.agents.Agent:{'trial': 180, 'steps_in_trial': 4, 'reward': 1000, 'perf_time': 0.010507399999998057, 'knowledge': 42.857142857142854, 'specificity': 0.24315068493150685, 'optimal': 80.0, 'optimal_reliable': 60.0, 'population': 73, 'numerosity': 73, 'reliable': 7}
# INFO:lcs.agents.Agent:{'trial': 210, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.0009535999999989997, 'knowledge': 50.0, 'specificity': 0.24315068493150685, 'optimal': 80.0, 'optimal_reliable': 80.0, 'population': 73, 'numerosity': 73, 'reliable': 8}
# INFO:lcs.agents.Agent:{'trial': 240, 'steps_in_trial': 4, 'reward': 1000, 'perf_time': 0.004839199999999266, 'knowledge': 50.0, 'specificity': 0.23717948717948717, 'optimal': 80.0, 'optimal_reliable': 80.0, 'population': 78, 'numerosity': 78, 'reliable': 9}
# INFO:lcs.agents.Agent:{'trial': 270, 'steps_in_trial': 2, 'reward': 1000, 'perf_time': 0.002762899999996904, 'knowledge': 50.0, 'specificity': 0.23575949367088608, 'optimal': 80.0, 'optimal_reliable': 80.0, 'population': 79, 'numerosity': 79, 'reliable': 11}
# INFO:lcs.agents.Agent:{'trial': 300, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.0028953999999998814, 'knowledge': 50.0, 'specificity': 0.2330246913580247, 'optimal': 80.0, 'optimal_reliable': 80.0, 'population': 81, 'numerosity': 81, 'reliable': 14}
# INFO:lcs.agents.Agent:{'trial': 30, 'steps_in_trial': 5, 'reward': 1000, 'perf_time': 0.009682999999998998, 'knowledge': 7.142857142857142, 'specificity': 0.21467391304347827, 'optimal': 60.0, 'optimal_reliable': 0.0, 'population': 46, 'numerosity': 46, 'reliable': 1}
# INFO:lcs.agents.Agent:{'trial': 60, 'steps_in_trial': 10, 'reward': 1000, 'perf_time': 0.019339199999997447, 'knowledge': 28.57142857142857, 'specificity': 0.21428571428571427, 'optimal': 60.0, 'optimal_reliable': 60.0, 'population': 56, 'numerosity': 56, 'reliable': 4}
# INFO:lcs.agents.Agent:{'trial': 90, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.0015950999999994053, 'knowledge': 28.57142857142857, 'specificity': 0.21774193548387097, 'optimal': 60.0, 'optimal_reliable': 60.0, 'population': 62, 'numerosity': 62, 'reliable': 4}
# INFO:lcs.agents.Agent:{'trial': 120, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.0011273000000002753, 'knowledge': 42.857142857142854, 'specificity': 0.21691176470588236, 'optimal': 60.0, 'optimal_reliable': 60.0, 'population': 68, 'numerosity': 68, 'reliable': 6}
# INFO:lcs.agents.Agent:{'trial': 150, 'steps_in_trial': 3, 'reward': 1000, 'perf_time': 0.0066744000000014125, 'knowledge': 42.857142857142854, 'specificity': 0.21428571428571427, 'optimal': 60.0, 'optimal_reliable': 60.0, 'population': 70, 'numerosity': 70, 'reliable': 8}
# INFO:lcs.agents.Agent:{'trial': 180, 'steps_in_trial': 6, 'reward': 1000, 'perf_time': 0.006083600000000189, 'knowledge': 50.0, 'specificity': 0.21746575342465754, 'optimal': 60.0, 'optimal_reliable': 60.0, 'population': 73, 'numerosity': 73, 'reliable': 12}
# INFO:lcs.agents.Agent:{'trial': 210, 'steps_in_trial': 4, 'reward': 1000, 'perf_time': 0.005799899999999525, 'knowledge': 64.28571428571429, 'specificity': 0.21746575342465754, 'optimal': 60.0, 'optimal_reliable': 60.0, 'population': 73, 'numerosity': 73, 'reliable': 16}
# INFO:lcs.agents.Agent:{'trial': 240, 'steps_in_trial': 13, 'reward': 1000, 'perf_time': 0.016461899999999474, 'knowledge': 64.28571428571429, 'specificity': 0.21621621621621623, 'optimal': 60.0, 'optimal_reliable': 60.0, 'population': 74, 'numerosity': 74, 'reliable': 18}
# INFO:lcs.agents.Agent:{'trial': 270, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.0010331000000007862, 'knowledge': 64.28571428571429, 'specificity': 0.215, 'optimal': 60.0, 'optimal_reliable': 60.0, 'population': 75, 'numerosity': 75, 'reliable': 20}
# INFO:lcs.agents.Agent:{'trial': 300, 'steps_in_trial': 4, 'reward': 1000, 'perf_time': 0.004347100000000381, 'knowledge': 64.28571428571429, 'specificity': 0.2138157894736842, 'optimal': 60.0, 'optimal_reliable': 60.0, 'population': 76, 'numerosity': 76, 'reliable': 21}

# %% [markdown]
# ### RUN ACS2ER Experiments

# %%
run_acs2er_experiments()
# Out:
# START - ACS2ER - 3
# INFO:lcs.agents.Agent:{'trial': 30, 'steps_in_trial': 4, 'reward': 1000, 'perf_time': 0.033153099999999824, 'knowledge': 7.142857142857142, 'specificity': 0.20404411764705882, 'optimal': 80.0, 'optimal_reliable': 0.0, 'population': 68, 'numerosity': 68, 'reliable': 1}
# INFO:lcs.agents.Agent:{'trial': 60, 'steps_in_trial': 3, 'reward': 1000, 'perf_time': 0.026265000000002203, 'knowledge': 42.857142857142854, 'specificity': 0.20666666666666667, 'optimal': 80.0, 'optimal_reliable': 60.0, 'population': 75, 'numerosity': 75, 'reliable': 12}
# INFO:lcs.agents.Agent:{'trial': 90, 'steps_in_trial': 5, 'reward': 1000, 'perf_time': 0.02252380000000187, 'knowledge': 57.14285714285714, 'specificity': 0.21044303797468356, 'optimal': 80.0, 'optimal_reliable': 60.0, 'population': 79, 'numerosity': 79, 'reliable': 21}
# INFO:lcs.agents.Agent:{'trial': 120, 'steps_in_trial': 2, 'reward': 1000, 'perf_time': 0.008383800000000718, 'knowledge': 71.42857142857143, 'specificity': 0.2109375, 'optimal': 80.0, 'optimal_reliable': 60.0, 'population': 80, 'numerosity': 80, 'reliable': 27}
# INFO:lcs.agents.Agent:{'trial': 150, 'steps_in_trial': 4, 'reward': 1000, 'perf_time': 0.01687740000000204, 'knowledge': 85.71428571428571, 'specificity': 0.2109375, 'optimal': 80.0, 'optimal_reliable': 80.0, 'population':
 'optimal': 80.0, 'optimal_reliable': 80.0, 'population': 73, 'numerosity': 73, 'reliable': 59}
# INFO:lcs.agents.Agent:{'trial': 300, 'steps_in_trial': 4, 'reward': 1000, 'perf_time': 0.014532500000001392, 'knowledge': 85.71428571428571, 'specificity': 0.2106164383561644, 'optimal': 80.0, 'optimal_reliable': 80.0, 'population': 73, 'numerosity': 73, 'reliable': 58}
# INFO:lcs.agents.Agent:{'trial': 30, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.003963800000001072, 'knowledge': 7.142857142857142, 'specificity': 0.21875, 'optimal': 100.0, 'optimal_reliable': 20.0, 'population': 68, 'numerosity': 68, 'reliable': 1}
# INFO:lcs.agents.Agent:{'trial': 60, 'steps_in_trial': 2, 'reward': 1000, 'perf_time': 0.008024400000003595, 'knowledge': 28.57142857142857, 'specificity': 0.21189024390243902, 'optimal': 100.0, 'optimal_reliable': 60.0, 'population': 82, 'numerosity': 82, 'reliable': 11}
# INFO:lcs.agents.Agent:{'trial': 90, 'steps_in_trial': 2, 'reward': 1000, 'perf_time': 0.009778199999999515, 'knowledge': 42.857142857142854, 'specificity': 0.2159090909090909, 'optimal': 100.0, 'optimal_reliable': 80.0, 'population': 88, 'numerosity': 88, 'reliable': 18}
# INFO:lcs.agents.Agent:{'trial': 120, 'steps_in_trial': 2, 'reward': 1000, 'perf_time': 0.009625700000000847, 'knowledge': 57.14285714285714, 'specificity': 0.2152777777777778, 'optimal': 100.0, 'optimal_reliable': 80.0, 'population': 90, 'numerosity': 90, 'reliable': 23}
# INFO:lcs.agents.Agent:{'trial': 150, 'steps_in_trial': 6, 'reward': 1000, 'perf_time': 0.04682900000000245, 'knowledge': 71.42857142857143, 'specificity': 0.21428571428571427, 'optimal': 100.0, 'optimal_reliable': 100.0, 'population': 91, 'numerosity': 91, 'reliable': 33}
# INFO:lcs.agents.Agent:{'trial': 180, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.004915199999999231, 'knowledge': 92.85714285714286, 'specificity': 0.21666666666666667, 'optimal': 100.0, 'optimal_reliable': 100.0, 'population': 90, 'numerosity': 90, 'reliable': 42}
# INFO:lcs.agents.Agent:{'trial': 210, 'steps_in_trial': 2, 'reward': 1000, 'perf_time': 0.02047149999999931, 'knowledge': 92.85714285714286, 'specificity': 0.21666666666666667, 'optimal': 100.0, 'optimal_reliable': 100.0, 'population': 90, 'numerosity': 90, 'reliable': 48}
# INFO:lcs.agents.Agent:{'trial': 240, 'steps_in_trial': 9, 'reward': 1000, 'perf_time': 0.07336320000000285, 'knowledge': 92.85714285714286, 'specificity': 0.21666666666666667, 'optimal': 100.0, 'optimal_reliable': 100.0, 'population': 90, 'numerosity': 90, 'reliable': 51}
# INFO:lcs.agents.Agent:{'trial': 270, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.006500699999996584, 'knowledge': 92.85714285714286, 'specificity': 0.22017045454545456, 'optimal': 100.0, 'optimal_reliable': 100.0, 'population': 88, 'numerosity': 88, 'reliable': 56}
# INFO:lcs.agents.Agent:{'trial': 300, 'steps_in_trial': 4, 'reward': 1000, 'perf_time': 0.024337500000001455, 'knowledge': 92.85714285714286, 'specificity': 0.22017045454545456, 'optimal': 100.0, 'optimal_reliable': 100.0, 'population': 88, 'numerosity': 88, 'reliable': 57}
# INFO:lcs.agents.Agent:{'trial': 30, 'steps_in_trial': 3, 'reward': 1000, 'perf_time': 0.01100919999999661, 'knowledge': 0.0, 'specificity': 0.213768115942029, 'optimal': 100.0, 'optimal_reliable': 0.0, 'population': 69, 'numerosity': 69, 'reliable': 0}
# INFO:lcs.agents.Agent:{'trial': 60, 'steps_in_trial': 2, 'reward': 1000, 'perf_time': 0.011997800000003167, 'knowledge': 7.142857142857142, 'specificity': 0.2077922077922078, 'optimal': 100.0, 'optimal_reliable': 20.0, 'population': 77, 'numerosity': 77, 'reliable': 3}
# INFO:lcs.agents.Agent:{'trial': 90, 'steps_in_trial': 2, 'reward': 1000, 'perf_time': 0.00893639999999607, 'knowledge': 35.714285714285715, 'specificity': 0.20679012345679013, 'optimal': 100.0, 'optimal_reliable': 60.0, 'population': 81, 'numerosity': 81, 'reliable': 15}
# INFO:lcs.agents.Agent:{'trial': 120, 'steps_in_trial': 2, 'reward': 1000, 'perf_time': 0.00776390000000049, 'knowledge': 57.14285714285714, 'specificity': 0.20987654320987653, 'optimal': 100.0, 'optimal_reliable': 80.0, 'population': 81, 'numerosity': 81, 'reliable': 21}
# INFO:lcs.agents.Agent:{'trial': 150, 'steps_in_trial': 5, 'reward': 1000, 'perf_time': 0.023956599999998218, 'knowledge': 64.28571428571429, 'specificity': 0.21036585365853658, 'optimal': 100.0, 'optimal_reliable': 80.0, 'population': 82, 'numerosity': 82, 'reliable': 34}
# INFO:lcs.agents.Agent:{'trial': 180, 'steps_in_trial': 13, 'reward': 1000, 'perf_time': 0.06664500000000118, 'knowledge': 71.42857142857143, 'specificity': 0.21084337349397592, 'optimal': 100.0, 'optimal_reliable': 100.0, 'population': 83, 'numerosity': 83, 'reliable': 47}
# INFO:lcs.agents.Agent:{'trial': 210, 'steps_in_trial': 2, 'reward': 1000, 'perf_time': 0.010484100000006435, 'knowledge': 78.57142857142857, 'specificity': 0.21189024390243902, 'optimal': 100.0, 'optimal_reliable': 100.0, 'population': 82, 'numerosity': 82, 'reliable': 52}
# INFO:lcs.agents.Agent:{'trial': 240, 'steps_in_trial': 2, 'reward': 1000, 'perf_time': 0.017187800000002085, 'knowledge': 78.57142857142857, 'specificity': 0.21450617283950618, 'optimal': 100.0, 'optimal_reliable': 100.0, 'population': 81, 'numerosity': 81, 'reliable': 52}
# INFO:lcs.agents.Agent:{'trial': 270, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.00898740000000231, 'knowledge': 78.57142857142857, 'specificity': 0.21341463414634146, 'optimal': 100.0, 'optimal_reliable': 100.0, 'population': 82, 'numerosity': 82, 'reliable': 56}
# INFO:lcs.agents.Agent:{'trial': 300, 'steps_in_trial': 8, 'reward': 1000, 'perf_time': 0.05703139999999962, 'knowledge': 85.71428571428571, 'specificity': 0.21341463414634146, 'optimal': 100.0, 'optimal_reliable': 100.0, 'population': 82, 'numerosity': 82, 'reliable': 63}
# END - ACS2ER - 3

# %%
run_acs2eer_experiments()
# Out:
# START - ACS2EER - 3
# INFO:lcs.agents.Agent:{'trial': 30, 'steps_in_trial': 4, 'reward': 1000, 'perf_time': 0.1095906000000042, 'knowledge': 14.285714285714285, 'specificity': 0.20489690721649484, 'optimal': 80.0, 'optimal_reliable': 20.0, 'population': 97, 'numerosity': 97, 'reliable': 20}
# INFO:lcs.agents.Agent:{'trial': 60, 'steps_in_trial': 3, 'reward': 1000, 'perf_time': 0
 'optimal': 100.0, 'optimal_reliable': 100.0, 'population': 102, 'numerosity': 102, 'reliable': 89}
# INFO:lcs.agents.Agent:{'trial': 180, 'steps_in_trial': 7, 'reward': 1000, 'perf_time': 0.009348199999990925, 'knowledge': 100.0, 'specificity': 0.22181372549019607, 'optimal': 100.0, 'optimal_reliable': 100.0, 'population': 102, 'numerosity': 102, 'reliable': 92}
# INFO:lcs.agents.Agent:{'trial': 210, 'steps_in_trial': 5, 'reward': 1000, 'perf_time': 0.014462799999989784, 'knowledge': 100.0, 'specificity': 0.22277227722772278, 'optimal': 100.0, 'optimal_reliable': 100.0, 'population': 101, 'numerosity': 101, 'reliable': 95}
# INFO:lcs.agents.Agent:{'trial': 240, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.05526729999999702, 'knowledge': 100.0, 'specificity': 0.22277227722772278, 'optimal': 100.0, 'optimal_reliable': 100.0, 'population': 101, 'numerosity': 101, 'reliable': 95}
# INFO:lcs.agents.Agent:{'trial': 270, 'steps_in_trial': 4, 'reward': 1000, 'perf_time': 0.010286100000001852, 'knowledge': 100.0, 'specificity': 0.22277227722772278, 'optimal': 100.0, 'optimal_reliable': 100.0, 'population': 101, 'numerosity': 101, 'reliable': 95}
# INFO:lcs.agents.Agent:{'trial': 300, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.02224800000000471, 'knowledge': 100.0, 'specificity': 0.22277227722772278, 'optimal': 100.0, 'optimal_reliable': 100.0, 'population': 101, 'numerosity': 101, 'reliable': 97}
# INFO:lcs.agents.Agent:{'trial': 30, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.07447360000000458, 'knowledge': 0.0, 'specificity': 0.2021604938271605, 'optimal': 100.0, 'optimal_reliable': 0.0, 'population': 81, 'numerosity': 81, 'reliable': 16}
# INFO:lcs.agents.Agent:{'trial': 60, 'steps_in_trial': 5, 'reward': 1000, 'perf_time': 0.08589920000000006, 'knowledge': 78.57142857142857, 'specificity': 0.20203488372093023, 'optimal': 100.0, 'optimal_reliable': 100.0, 'population': 86, 'numerosity': 86, 'reliable': 46}
# INFO:lcs.agents.Agent:{'trial': 90, 'steps_in_trial': 5, 'reward': 1000, 'perf_time': 0.01984709999999268, 'knowledge': 92.85714285714286, 'specificity': 0.20441176470588235, 'optimal': 100.0, 'optimal_reliable': 100.0, 'population': 85, 'numerosity': 85, 'reliable': 57}
# INFO:lcs.agents.Agent:{'trial': 120, 'steps_in_trial': 2, 'reward': 1000, 'perf_time': 0.10998109999999883, 'knowledge': 100.0, 'specificity': 0.20684523809523808, 'optimal': 100.0, 'optimal_reliable': 100.0, 'population': 84, 'numerosity': 84, 'reliable': 64}
# INFO:lcs.agents.Agent:{'trial': 150, 'steps_in_trial': 7, 'reward': 1000, 'perf_time': 0.1156706000000014, 'knowledge': 100.0, 'specificity': 0.20783132530120482, 'optimal': 100.0, 'optimal_reliable': 100.0, 'population': 83, 'numerosity': 83, 'reliable': 66}
# INFO:lcs.agents.Agent:{'trial': 180, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.009593899999998712, 'knowledge': 100.0, 'specificity': 0.20933734939759036, 'optimal': 100.0, 'optimal_reliable': 100.0, 'population': 83, 'numerosity': 83, 'reliable': 68}
# INFO:lcs.agents.Agent:{'trial': 210, 'steps_in_trial': 3, 'reward': 1000, 'perf_time': 0.011373100000000136, 'knowledge': 100.0, 'specificity': 0.21189024390243902, 'optimal': 100.0, 'optimal_reliable': 100.0, 'population': 82, 'numerosity': 82, 'reliable': 73}
# INFO:lcs.agents.Agent:{'trial': 240, 'steps_in_trial': 5, 'reward': 1000, 'perf_time': 0.011862899999997012, 'knowledge': 100.0, 'specificity': 0.21189024390243902, 'optimal': 100.0, 'optimal_reliable': 100.0, 'population': 82, 'numerosity': 82, 'reliable': 76}
# INFO:lcs.agents.Agent:{'trial': 270, 'steps_in_trial': 2, 'reward': 1000, 'perf_time': 0.06068949999999518, 'knowledge': 100.0, 'specificity': 0.21189024390243902, 'optimal': 100.0, 'optimal_reliable': 100.0, 'population': 82, 'numerosity': 82, 'reliable': 78}
# INFO:lcs.agents.Agent:{'trial': 300, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.007253599999998528, 'knowledge': 100.0, 'specificity': 0.21189024390243902, 'optimal': 100.0, 'optimal_reliable': 100.0, 'population': 82, 'numerosity': 82, 'reliable': 78}
# INFO:lcs.agents.Agent:{'trial': 30, 'steps_in_trial': 11, 'reward': 1000, 'perf_time': 0.1140204999999952, 'knowledge': 28.57142857142857, 'specificity': 0.19917582417582416, 'optimal': 100.0, 'optimal_reliable': 40.0, 'population': 91, 'numerosity': 91, 'reliable': 24}
# INFO:lcs.agents.Agent:{'trial': 60, 'steps_in_trial': 6, 'reward': 1000, 'perf_time': 0.02250599999999281, 'knowledge': 78.57142857142857, 'specificity': 0.20977011494252873, 'optimal': 100.0, 'optimal_reliable': 80.0, 'population': 87, 'numerosity': 87, 'reliable': 57}
# INFO:lcs.agents.Agent:{'trial': 90, 'steps_in_trial': 2, 'reward': 1000, 'perf_time': 0.047188700000006634, 'knowledge': 100.0, 'specificity': 0.20977011494252873, 'optimal': 100.0, 'optimal_reliable': 100.0, 'population': 87, 'numerosity': 87, 'reliable': 68}
# INFO:lcs.agents.Agent:{'trial': 120, 'steps_in_trial': 4, 'reward': 1000, 'perf_time': 0.034035700000004, 'knowledge': 100.0, 'specificity': 0.21470588235294116, 'optimal': 100.0, 'optimal_reliable': 100.0, 'population': 85, 'numerosity': 85, 'reliable': 76}
# INFO:lcs.agents.Agent:{'trial': 150, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.07361559999999656, 'knowledge': 100.0, 'specificity': 0.21470588235294116, 'optimal': 100.0, 'optimal_reliable': 100.0, 'population': 85, 'numerosity': 85, 'reliable': 80}
# INFO:lcs.agents.Agent:{'trial': 180, 'steps_in_trial': 2, 'reward': 1000, 'perf_time': 0.011764300000010053, 'knowledge': 100.0, 'specificity': 0.21470588235294116, 'optimal': 100.0, 'optimal_reliable': 100.0, 'population': 85, 'numerosity': 85, 'reliable': 82}
# INFO:lcs.agents.Agent:{'trial': 210, 'steps_in_trial': 2, 'reward': 1000, 'perf_time': 0.028878599999998755, 'knowledge': 100.0, 'specificity': 0.21470588235294116, 'optimal': 100.0, 'optimal_reliable': 100.0, 'population': 85, 'numerosity': 85, 'reliable': 82}
# INFO:lcs.agents.Agent:{'trial': 240, 'steps_in_trial': 5, 'reward': 1000, 'perf_time': 0.01291920000001312, 'knowledge': 100.0, 'specificity': 0.21470588235294116, 'optimal': 100.0, 'optimal_reliable': 100.0, 'population': 85, 'numerosity': 85, 'reliable': 84}
# INFO:lcs.agents.Agent:{'trial': 270, 'steps_in_trial': 1, 'reward': 1000, 'perf_time': 0.0069246000000049435, 'knowledge': 100.0, 'specificity': 0.21470588235294116, 'optimal': 100.0, 'optimal_reliable': 100.0, 'population': 85, 'numerosity': 85, 'reliable': 84}
# INFO:lcs.agents.Agent:{'trial': 300, 'steps_in_trial': 6, 'reward': 1000, 'perf_time': 0.07008639999999389, 'knowledge': 100.0, 'specificity': 0.21470588235294116, 'optimal': 100.0, 'optimal_reliable': 100.0, 'population': 85, 'numerosity': 85, 'reliable': 84}
# END - ACS2EER - 3
