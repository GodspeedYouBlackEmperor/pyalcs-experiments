# %%
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

import utils.analyze_load_utils
import utils.analyze_utils

import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

import importlib

# %% [markdown]
# # EXPERIMENT CONFIGURATION

# %%
BASE = 'MPX'
ENV = f'boolean-multiplexer-{6}bit-v0'
FRIENDLY_ENV = 'Multiplexer 6-bit'
ER_SAMPLES_NUMBER_LIST = ['3-ER', '3-pER_reward', '3-pER_unique',  '3-pER_unique_reward']
EXPERIMENT_NAME = "MPX6_PER_EXP1"

# %%
importlib.reload(utils.analyze_load_utils)
loader = utils.analyze_load_utils.Loader(BASE, EXPERIMENT_NAME, ENV, M = ER_SAMPLES_NUMBER_LIST)
acs2_data, acs2er_data, acs2_data_full, acs2er_data_full = loader.load()

# %%
importlib.reload(utils.analyze_utils)
config = utils.analyze_utils.AnalyzerConfiguration(
  BASE_NAME=BASE, 
  EXP_NAME=EXPERIMENT_NAME,
  ENV_NAME=ENV,
  FRIENDLY_ENV_NAME=FRIENDLY_ENV,
  M=ER_SAMPLES_NUMBER_LIST,
  DATA_BASE_PATH=BASE)
analyzer = utils.analyze_utils.Analyzer(acs2_data, acs2er_data, config, acs2_data_full, acs2er_data_full)

# %%
# analyzer.plot_knowledge(exploit_avg_win=50, explore_avg_win=50, width=0.5)
analyzer.plot_reward(exploit_avg_win=100, explore_avg_win=500, width=0.5)
analyzer.plot_specificity(exploit_avg_win=50, explore_avg_win=50, width=0.5)
analyzer.plot_classifiers(width=0.5)

# %%
analyzer.compare_reward_average_welch_test()
analyzer.compare_reward_exploit_average_welch_test()
# Out:
#                                ACS2-ER m--1         ACS2-ER m-3-ER       ACS2-ER m-3-pER_reward    ACS2-ER m-3-pER_unique    ACS2-ER m-3-pER_unique_reward
# -----------------------------  -------------------  -------------------  ------------------------  ------------------------  -------------------------------
# ACS2-ER m--1                   s: 0.0, p: 1.0       s: -0.073, p: 0.946  s: -0.664, p: 0.543       s: 0.085, p: 0.936        s: -4.299, p: 0.013
# ACS2-ER m-3-ER                 s: 0.073, p: 0.946   s: 0.0, p: 1.0       s: -0.408, p: 0.704       s: 0.115, p: 0.914        s: -1.663, p: 0.172
# ACS2-ER m-3-pER_reward         s: 0.664, p: 0.543   s: 0.408, p: 0.704   s: 0.0, p: 1.0            s: 0.423, p: 0.694        s: -1.318, p: 0.258
# ACS2-ER m-3-pER_unique         s: -0.085, p: 0.936  s: -0.115, p: 0.914  s: -0.423, p: 0.694       s: 0.0, p: 1.0            s: -1.228, p: 0.287
# ACS2-ER m-3-pER_unique_reward  s: 4.299, p: 0.013   s: 1.663, p: 0.172   s: 1.318, p: 0.258        s: 1.228, p: 0.287        s: 0.0, p: 1.0
#                                ACS2-ER m--1    ACS2-ER m-3-ER    ACS2-ER m-3-pER_reward    ACS2-ER m-3-pER_unique    ACS2-ER m-3-pER_unique_reward
# -----------------------------  --------------  ----------------  ------------------------  ------------------------  -------------------------------
# ACS2-ER m--1                   s: nan, p: nan  s: nan, p: nan    s: nan, p: nan            s: nan, p: nan            s: nan, p: nan
# ACS2-ER m-3-ER                 s: nan, p: nan  s: nan, p: nan    s: nan, p: nan            s: nan, p: nan            s: nan, p: nan
# ACS2-ER m-3-pER_reward         s: nan, p: nan  s: nan, p: nan    s: nan, p: nan            s: nan, p: nan            s: nan, p: nan
# ACS2-ER m-3-pER_unique         s: nan, p: nan  s: nan, p: nan    s: nan, p: nan            s: nan, p: nan            s: nan, p: nan
# ACS2-ER m-3-pER_unique_reward  s: nan, p: nan  s: nan, p: nan    s: nan, p: nan            s: nan, p: nan            s: nan, p: nan
