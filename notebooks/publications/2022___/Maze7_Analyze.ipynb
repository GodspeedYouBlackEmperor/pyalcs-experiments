# %%
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

import utils.analyze_load_utils
import utils.analyze_utils

import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

import importlib

# %% [markdown]
# # EXPERIMENT CONFIGURATION

# %%
BASE = 'MAZE'
ENV = "Maze7-v0"
FRIENDLY_ENV = "MAZE 7" 
ER_SAMPLES_NUMBER_LIST = ['3', '3-pER_reward', '3-pER_unique', '3-RER']
EXPERIMENT_NAME = "Maze7_TEST10"

# %%
importlib.reload(utils.analyze_load_utils)
loader = utils.analyze_load_utils.Loader(BASE, EXPERIMENT_NAME, ENV, M = ER_SAMPLES_NUMBER_LIST)
acs2_data, acs2er_data, acs2_data_full, acs2er_data_full = loader.load()

# %%
importlib.reload(utils.analyze_utils)
config = utils.analyze_utils.AnalyzerConfiguration(
  BASE_NAME=BASE, 
  EXP_NAME=EXPERIMENT_NAME,
  FRIENDLY_ENV_NAME=FRIENDLY_ENV,
  ENV_NAME=ENV,
  M=ER_SAMPLES_NUMBER_LIST,
  DATA_BASE_PATH=BASE)
analyzer = utils.analyze_utils.Analyzer(acs2_data, acs2er_data, config, acs2_data_full, acs2er_data_full)

# %%
analyzer.plot_knowledge(width=0.5)
analyzer.plot_steps(exploit_avg_win=20, explore_avg_win=20, width=0.5)
analyzer.plot_specificity(exploit_avg_win=10, explore_avg_win=10, width=0.5)
analyzer.plot_classifiers(width=0.5)

# %%
analyzer.compare_knowledge_above_threshold_welch_test(95)
analyzer.compare_steps_average_welch_test(0, 5000)
# Out:
#                         ACS2-ER m--1         ACS2-ER m-3          ACS2-ER m-3-pER_reward    ACS2-ER m-3-pER_unique    ACS2-ER m-3-RER
# ----------------------  -------------------  -------------------  ------------------------  ------------------------  ------------------
# ACS2-ER m--1            s: nan, p: nan       s: 8.537, p: 0.0     s: 3.453, p: 0.006        s: 113.204, p: 0.0        s: 7.459, p: 0.0
# ACS2-ER m-3             s: -8.537, p: 0.0    s: 0.0, p: 1.0       s: -0.576, p: 0.577       s: 6.262, p: 0.0          s: 0.009, p: 0.993
# ACS2-ER m-3-pER_reward  s: -3.453, p: 0.006  s: 0.576, p: 0.577   s: 0.0, p: 1.0            s: 3.659, p: 0.004        s: 0.566, p: 0.584
# ACS2-ER m-3-pER_unique  s: -113.204, p: 0.0  s: -6.262, p: 0.0    s: -3.659, p: 0.004       s: 0.0, p: 1.0            s: -5.46, p: 0.0
# ACS2-ER m-3-RER         s: -7.459, p: 0.0    s: -0.009, p: 0.993  s: -0.566, p: 0.584       s: 5.46, p: 0.0           s: 0.0, p: 1.0
#                         ACS2-ER m--1         ACS2-ER m-3         ACS2-ER m-3-pER_reward    ACS2-ER m-3-pER_unique    ACS2-ER m-3-RER
# ----------------------  -------------------  ------------------  ------------------------  ------------------------  -------------------
# ACS2-ER m--1            s: 0.0, p: 1.0       s: 4.644, p: 0.005  s: 1.888, p: 0.089        s: 3.777, p: 0.009        s: 3.062, p: 0.015
# ACS2-ER m-3             s: -4.644, p: 0.005  s: 0.0, p: 1.0      s: -2.712, p: 0.038       s: -2.031, p: 0.077       s: -1.859, p: 0.113
# ACS2-ER m-3-pER_reward  s: -1.888, p: 0.089  s: 2.712, p: 0.038  s: 0.0, p: 1.0            s: 1.731, p: 0.13         s: 1.107, p: 0.297
# ACS2-ER m-3-pER_unique  s: -3.777, p: 0.009  s: 2.031, p: 0.077  s: -1.731, p: 0.13        s: 0.0, p: 1.0            s: -0.597, p: 0.568
# ACS2-ER m-3-RER         s: -3.062, p: 0.015  s: 1.859, p: 0.113  s: -1.107, p: 0.297       s: 0.597, p: 0.568        s: 0.0, p: 1.0
