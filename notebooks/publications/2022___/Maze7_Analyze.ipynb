# %%
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

import utils.analyze_load_utils
import utils.analyze_utils

import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

import importlib

# %% [markdown]
# # EXPERIMENT CONFIGURATION

# %%
BASE = 'MAZE'
ENV = "Maze7-v0"
FRIENDLY_ENV = "MAZE 7" 
ER_SAMPLES_NUMBER_LIST = ['3-ER', '3-pER_reward', '3-pER_unique', '3-pER_unique_reward', '3-RER']
EXPERIMENT_NAME = "Maze7_PER_EXP2"

# %%
importlib.reload(utils.analyze_load_utils)
loader = utils.analyze_load_utils.Loader(BASE, EXPERIMENT_NAME, ENV, M = ER_SAMPLES_NUMBER_LIST)
acs2_data, acs2er_data, acs2_data_full, acs2er_data_full = loader.load()

# %%
importlib.reload(utils.analyze_utils)
config = utils.analyze_utils.AnalyzerConfiguration(
  BASE_NAME=BASE, 
  EXP_NAME=EXPERIMENT_NAME,
  FRIENDLY_ENV_NAME=FRIENDLY_ENV,
  ENV_NAME=ENV,
  M=ER_SAMPLES_NUMBER_LIST,
  DATA_BASE_PATH=BASE)
analyzer = utils.analyze_utils.Analyzer(acs2_data, acs2er_data, config, acs2_data_full, acs2er_data_full)

# %%
analyzer.plot_knowledge(width=0.5)
analyzer.plot_optimal(width=0.5)
analyzer.plot_optimal_reliable(width=0.5)
analyzer.plot_steps(exploit_avg_win=100, explore_avg_win=100, width=0.5)
# analyzer.plot_avg_steps(exploit_avg_win=10, explore_avg_win=10, width=0.5)
analyzer.plot_specificity(exploit_avg_win=10, explore_avg_win=10, width=0.5)
analyzer.plot_classifiers(width=0.5)

# %%
analyzer.compare_knowledge_above_threshold_welch_test(95)
analyzer.compare_steps_average_welch_test(0, 5000)
# Out:
#                                ACS2-ER m--1        ACS2-ER m-3-ER      ACS2-ER m-3-pER_reward    ACS2-ER m-3-pER_unique    ACS2-ER m-3-pER_unique_reward    ACS2-ER m-3-RER
# -----------------------------  ------------------  ------------------  ------------------------  ------------------------  -------------------------------  -------------------
# ACS2-ER m--1                   s: 0.0, p: 1.0      s: 10.397, p: 0.0   s: 7.66, p: 0.0           s: 12.063, p: 0.0         s: 12.004, p: 0.0                s: 10.318, p: 0.0
# ACS2-ER m-3-ER                 s: -10.397, p: 0.0  s: 0.0, p: 1.0      s: -3.176, p: 0.01        s: 7.484, p: 0.0          s: 7.097, p: 0.0                 s: 0.63, p: 0.543
# ACS2-ER m-3-pER_reward         s: -7.66, p: 0.0    s: 3.176, p: 0.01   s: 0.0, p: 1.0            s: 6.043, p: 0.0          s: 5.939, p: 0.0                 s: 3.287, p: 0.008
# ACS2-ER m-3-pER_unique         s: -12.063, p: 0.0  s: -7.484, p: 0.0   s: -6.043, p: 0.0         s: 0.0, p: 1.0            s: -1.109, p: 0.293              s: -3.866, p: 0.003
# ACS2-ER m-3-pER_unique_reward  s: -12.004, p: 0.0  s: -7.097, p: 0.0   s: -5.939, p: 0.0         s: 1.109, p: 0.293        s: 0.0, p: 1.0                   s: -3.685, p: 0.004
# ACS2-ER m-3-RER                s: -10.318, p: 0.0  s: -0.63, p: 0.543  s: -3.287, p: 0.008       s: 3.866, p: 0.003        s: 3.685, p: 0.004               s: 0.0, p: 1.0
#                                ACS2-ER m--1         ACS2-ER m-3-ER      ACS2-ER m-3-pER_reward    ACS2-ER m-3-pER_unique    ACS2-ER m-3-pER_unique_reward    ACS2-ER m-3-RER
# -----------------------------  -------------------  ------------------  ------------------------  ------------------------  -------------------------------  ------------------
# ACS2-ER m--1                   s: 0.0, p: 1.0       s: 5.892, p: 0.001  s: 5.108, p: 0.001        s: -1.05, p: 0.337        s: 0.126, p: 0.904               s: 6.177, p: 0.001
# ACS2-ER m-3-ER                 s: -5.892, p: 0.001  s: 0.0, p: 1.0      s: -0.805, p: 0.441       s: -2.601, p: 0.047       s: -1.448, p: 0.206              s: 0.103, p: 0.92
# ACS2-ER m-3-pER_reward         s: -5.108, p: 0.001  s: 0.805, p: 0.441  s: 0.0, p: 1.0            s: -2.463, p: 0.055       s: -1.31, p: 0.245               s: 0.982, p: 0.358
# ACS2-ER m-3-pER_unique         s: 1.05, p: 0.337    s: 2.601, p: 0.047  s: 2.463, p: 0.055        s: 0.0, p: 1.0            s: 0.867, p: 0.406               s: 2.62, p: 0.047
# ACS2-ER m-3-pER_unique_reward  s: -0.126, p: 0.904  s: 1.448, p: 0.206  s: 1.31, p: 0.245         s: -0.867, p: 0.406       s: 0.0, p: 1.0                   s: 1.464, p: 0.203
# ACS2-ER m-3-RER                s: -6.177, p: 0.001  s: -0.103, p: 0.92  s: -0.982, p: 0.358       s: -2.62, p: 0.047        s: -1.464, p: 0.203              s: 0.0, p: 1.0
