# %%
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

import analyze_load_utils
import analyze_utils

# %% [markdown]
# # EXPERIMENT CONFIGURATION

# %%
BASE = 'MAZE'
ENV = "Maze5-v0" 
FRIENDLY_ENV = "MAZE 5" 
ER_SAMPLES_NUMBER_LIST = [1,3,5,13]
EXPERIMENT_NAME = "20"

config = analyze_utils.AnalyzerConfiguration(
  BASE_NAME=BASE, 
  EXP_NAME=EXPERIMENT_NAME,
  ENV_NAME=ENV,
  FRIENDLY_ENV_NAME=FRIENDLY_ENV,
  M=ER_SAMPLES_NUMBER_LIST,
  DATA_BASE_PATH=BASE)

# %%
loader = analyze_load_utils.Loader(BASE, EXPERIMENT_NAME, ENV, BASE, ER_SAMPLES_NUMBER_LIST)
acs2_data, acs2er_data = loader.load()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# E:\_ZSSE\Anaconda\envs\pyalcs-experiments-acs2er\lib\site-packages\pandas\core\series.py in __setitem__(self, key, value)
#    1061         try:
# -> 1062             self._set_with_engine(key, value)
#    1063         except (KeyError, ValueError):
#
# E:\_ZSSE\Anaconda\envs\pyalcs-experiments-acs2er\lib\site-packages\pandas\core\series.py in _set_with_engine(self, key, value)
#    1094         # fails with AttributeError for IntervalIndex
# -> 1095         loc = self.index._engine.get_loc(key)
#    1096         # error: Argument 1 to "validate_numeric_casting" has incompatible type
#
# E:\_ZSSE\Anaconda\envs\pyalcs-experiments-acs2er\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# E:\_ZSSE\Anaconda\envs\pyalcs-experiments-acs2er\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'steps'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32572\3397581153.py in <module>
#       1 loader = analyze_load_utils.Loader(BASE, EXPERIMENT_NAME, ENV, BASE, ER_SAMPLES_NUMBER_LIST)
# ----> 2 acs2_data, acs2er_data = loader.load()
#
# e:\_ZSSE\_PM_CODE\pyalcs-experiments\notebooks\GECCO_2022\analyze_load_utils.py in load(self)
#      24             return data
#      25
# ---> 26         return (_get_acs2_experiment_data(), _get_acs2er_experiments_data())
#      27
#      28     def _load_data(self, path, file_name):
#
# e:\_ZSSE\_PM_CODE\pyalcs-experiments\notebooks\GECCO_2022\analyze_load_utils.py in _get_acs2_experiment_data()
#      11         def _get_acs2_experiment_data():
#      12             explore_metrics, exploit_metrics, population, env = self._load_acs2_experiment_data()
# ---> 13             metrics_average = self._parse_metrics_to_df(explore_metrics, exploit_metrics)
#      14
#      15             return (metrics_average, population[0], env[0])
#
# e:\_ZSSE\_PM_CODE\pyalcs-experiments\notebooks\GECCO_2022\analyze_load_utils.py in _parse_metrics_to_df(self, explore_metrics, exploit_metrics)
#      81             explore_df = pd.DataFrame(explore_metrics[i])
#      82             exploit_df = pd.DataFrame(exploit_metrics[i])
# ---> 83             explore_df = explore_df.apply(extract_details, axis=1)
#      84             exploit_df = exploit_df.apply(extract_details, axis=1)
#      85
#
# E:\_ZSSE\Anaconda\envs\pyalcs-experiments-acs2er\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# E:\_ZSSE\Anaconda\envs\pyalcs-experiments-acs2er\lib\site-packages\pandas\core\apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# E:\_ZSSE\Anaconda\envs\pyalcs-experiments-acs2er\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     810
#     811     def apply_standard(self):
# --> 812         results, res_index = self.apply_series_generator()
#     813
#     814         # wrap results
#
# E:\_ZSSE\Anaconda\envs\pyalcs-experiments-acs2er\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     826             for i, v in enumerate(series_gen):
#     827                 # ignore SettingWithCopy here in case the user mutates
# --> 828                 results[i] = self.f(v)
#     829                 if isinstance(results[i], ABCSeries):
#     830                     # If we have a view on v, we need to make a copy because
#
# e:\_ZSSE\_PM_CODE\pyalcs-experiments\notebooks\GECCO_2022\analyze_load_utils.py in extract_details(row)
#      73     def _parse_metrics_to_df(self, explore_metrics, exploit_metrics):
#      74         def extract_details(row):
# ---> 75             row['steps'] = row['steps_in_trial']
#      76             return row
#      77
#
# E:\_ZSSE\Anaconda\envs\pyalcs-experiments-acs2er\lib\site-packages\pandas\core\series.py in __setitem__(self, key, value)
#    1068             else:
#    1069                 # GH#12862 adding a new key to the Series
# -> 1070                 self.loc[key] = value
#    1071
#    1072         except TypeError as err:
#
# E:\_ZSSE\Anaconda\envs\pyalcs-experiments-acs2er\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     721
#     722         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 723         iloc._setitem_with_indexer(indexer, value, self.name)
#     724
#     725     def _validate_key(self, key, axis: int):
#
# E:\_ZSSE\Anaconda\envs\pyalcs-experiments-acs2er\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1722
#    1723             if missing:
# -> 1724                 self._setitem_with_indexer_missing(indexer, value)
#    1725                 return
#    1726
#
# E:\_ZSSE\Anaconda\envs\pyalcs-experiments-acs2er\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer_missing(self, indexer, value)
#    2000                 # GH#22717 handle casting compatibility that np.concatenate
#    2001                 #  does incorrectly
# -> 2002                 new_values = concat_compat([self.obj._values, new_values])
#    2003             self.obj._mgr = self.obj._constructor(
#    2004                 new_values, index=new_index, name=self.obj.name
#
# E:\_ZSSE\Anaconda\envs\pyalcs-experiments-acs2er\lib\site-packages\pandas\core\dtypes\concat.py in concat_compat(to_concat, axis, ea_compat_axis)
#     149                 to_concat = [x.astype("object") for x in to_concat]
#     150
# --> 151     return np.concatenate(to_concat, axis=axis)
#     152
#     153
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
import importlib
importlib.reload(analyze_utils)
analyzer = analyze_utils.Analyzer(acs2_data, acs2er_data, config)

# %%
analyzer.plot_knowledge()
analyzer.plot_steps(exploit_avg_win=100, explore_avg_win=100)
analyzer.plot_classifiers()
analyzer.plot_classifiers(use_markers=True, density=100, width=0.25)
