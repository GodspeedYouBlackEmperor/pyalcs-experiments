# %%
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

import analyze_load_utils
import analyze_utils

import importlib

# %% [markdown]
# # EXPERIMENT CONFIGURATION

# %%
BASE = 'FSW'
ENV = "fsw-40-v0" 
FRIENDLY_ENV = 'FSW 40'
ER_SAMPLES_NUMBER_LIST = [1,3,5,13]
EXPERIMENT_NAME = "810"

# %%
importlib.reload(analyze_load_utils)
loader = analyze_load_utils.Loader(BASE, EXPERIMENT_NAME, ENV, BASE, ER_SAMPLES_NUMBER_LIST)
acs2_data, acs2er_data, acs2_data_full, acs2er_data_full = loader.load()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20068\1435236162.py in <module>
#       1 importlib.reload(analyze_load_utils)
#       2 loader = analyze_load_utils.Loader(BASE, EXPERIMENT_NAME, ENV, BASE, ER_SAMPLES_NUMBER_LIST)
# ----> 3 acs2_data, acs2er_data, acs2_data_full, acs2er_data_full = loader.load()
#
# e:\_ZSSE\_PM_CODE\pyalcs-experiments\notebooks\GECCO_2022\analyze_load_utils.py in load(self)
#      27             return data, data_full
#      28
# ---> 29         acs2_data, acs2_full_data = _get_acs2_experiment_data()
#      30         acs2er_data, acs2er_full_data = _get_acs2er_experiments_data()
#      31         return (acs2_data, acs2er_data, acs2_full_data, acs2er_full_data)
#
# e:\_ZSSE\_PM_CODE\pyalcs-experiments\notebooks\GECCO_2022\analyze_load_utils.py in _get_acs2_experiment_data()
#      12         def _get_acs2_experiment_data():
#      13             explore_metrics, exploit_metrics, population, env = self._load_acs2_experiment_data()
# ---> 14             metrics_average, full_metrics = self._parse_metrics_to_df(explore_metrics, exploit_metrics)
#      15
#      16             return (metrics_average, population[0], env[0]), full_metrics
#
# e:\_ZSSE\_PM_CODE\pyalcs-experiments\notebooks\GECCO_2022\analyze_load_utils.py in _parse_metrics_to_df(self, explore_metrics, exploit_metrics)
#      97                 exploit_df = pd.DataFrame(exploit_metrics[i])
#      98                 explore_df = explore_df.apply(extract_details, axis=1)
# ---> 99                 exploit_df = exploit_df.apply(extract_details, axis=1)
#     100
#     101                 explore_df['phase'] = 'explore'
#
# E:\_ZSSE\Anaconda\envs\pyalcs-experiments-acs2er\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# E:\_ZSSE\Anaconda\envs\pyalcs-experiments-acs2er\lib\site-packages\pandas\core\apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# E:\_ZSSE\Anaconda\envs\pyalcs-experiments-acs2er\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     813
#     814         # wrap results
# --> 815         return self.wrap_results(results, res_index)
#     816
#     817     def apply_series_generator(self) -> tuple[ResType, Index]:
#
# E:\_ZSSE\Anaconda\envs\pyalcs-experiments-acs2er\lib\site-packages\pandas\core\apply.py in wrap_results(self, results, res_index)
#     839         # see if we can infer the results
#     840         if len(results) > 0 and 0 in results and is_sequence(results[0]):
# --> 841             return self.wrap_results_for_axis(results, res_index)
#     842
#     843         # dict of scalars
#
# E:\_ZSSE\Anaconda\envs\pyalcs-experiments-acs2er\lib\site-packages\pandas\core\apply.py in wrap_results_for_axis(self, results, res_index)
#     986         # we may want to infer results
#     987         else:
# --> 988             result = self.infer_to_same_shape(results, res_index)
#     989
#     990         return result
#
# E:\_ZSSE\Anaconda\envs\pyalcs-experiments-acs2er\lib\site-packages\pandas\core\apply.py in infer_to_same_shape(self, results, res_index)
#     992     def infer_to_same_shape(self, results: ResType, res_index: Index) -> DataFrame:
#     993         """infer the results to the same shape as the input object"""
# --> 994         result = self.obj._constructor(data=results)
#     995         result = result.T
#     996
#
# E:\_ZSSE\Anaconda\envs\pyalcs-experiments-acs2er\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# E:\_ZSSE\Anaconda\envs\pyalcs-experiments-acs2er\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     463
#     464     return arrays_to_mgr(
# --> 465         arrays, data_names, index, columns, dtype=dtype, typ=typ, consolidate=copy
#     466     )
#     467
#
# E:\_ZSSE\Anaconda\envs\pyalcs-experiments-acs2er\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity, typ, consolidate)
#     117         # figure out the index, if necessary
#     118         if index is None:
# --> 119             index = _extract_index(arrays)
#     120         else:
#     121             index = ensure_index(index)
#
# E:\_ZSSE\Anaconda\envs\pyalcs-experiments-acs2er\lib\site-packages\pandas\core\internals\construction.py in _extract_index(data)
#     626
#     627         if have_series:
# --> 628             index = union_indexes(indexes)
#     629         elif have_dicts:
#     630             index = union_indexes(indexes, sort=False)
#
# E:\_ZSSE\Anaconda\envs\pyalcs-experiments-acs2er\lib\site-packages\pandas\core\indexes\api.py in union_indexes(indexes, sort)
#     223     elif kind == "array":
#     224         index = indexes[0]
# --> 225         if not all(index.equals(other) for other in indexes[1:]):
#     226             index = _unique_indices(indexes)
#     227
#
# E:\_ZSSE\Anaconda\envs\pyalcs-experiments-acs2er\lib\site-packages\pandas\core\indexes\api.py in <genexpr>(.0)
#     223     elif kind == "array":
#     224         index = indexes[0]
# --> 225         if not all(index.equals(other) for other in indexes[1:]):
#     226             index = _unique_indices(indexes)
#     227
#
# KeyboardInterrupt:

# %%
config = analyze_utils.AnalyzerConfiguration(
  BASE_NAME=BASE, 
  EXP_NAME=EXPERIMENT_NAME,
  ENV_NAME=ENV,
  FRIENDLY_ENV_NAME=FRIENDLY_ENV,
  M=ER_SAMPLES_NUMBER_LIST,
  DATA_BASE_PATH=BASE)
  
importlib.reload(analyze_utils)
analyzer = analyze_utils.Analyzer(acs2_data, acs2er_data, config, acs2_data_full, acs2er_data_full)

# %%
analyzer.plot_knowledge(width=0.5)
analyzer.plot_steps(exploit_avg_win=100, explore_avg_win=100, width=0.5)
analyzer.plot_classifiers(width=0.5)
# analyzer.plot_classifiers(use_markers=True, density=100, width=0.5)

# %%
analyzer.print_knowledge_above_threshold(95) # it's just average

print("\n", '########', '\n', "WELCH's T-test:")

analyzer.compare_knowledge_above_threshold_welch_test(95)  # all 30 observations used
analyzer.compare_steps_average_welch_test(0, 5000) # all 30 observations used
# Out:
# ACS: Knowledge over 95 % at trial 147.0
# ACS-ER m-1: Knowledge over 95 % at trial 159.0
# ACS-ER m-3: Knowledge over 95 % at trial 81.0
# ACS-ER m-5: Knowledge over 95 % at trial 68.0
# ACS-ER m-13: Knowledge over 95 % at trial 38.0
#
#  ########
#  WELCH's T-test:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20068\3354907619.py in <module>
#       3 print("\n", '########', '\n', "WELCH's T-test:")
#       4
# ----> 5 analyzer.compare_knowledge_above_threshold_welch_test(95)  # all 30 observations used
#       6 analyzer.compare_steps_average_welch_test(0, 5000) # all 30 observations used
#
# e:\_ZSSE\_PM_CODE\pyalcs-experiments\notebooks\GECCO_2022\analyze_utils.py in compare_knowledge_above_threshold_welch_test(self, threshold)
#     351         avg = [(m, np.mean(d)) for m, d in info]
#     352         self.__save_to_csv(avg, 'temp_knowledge_avg')
# --> 353         self.__save_info_mean_to_csv(info, 'knowledge95')
#     354
#     355         test_results = []
#
# e:\_ZSSE\_PM_CODE\pyalcs-experiments\notebooks\GECCO_2022\analyze_utils.py in __save_info_mean_to_csv(self, info, file_name)
#     315
#     316         df = pd.DataFrame([avg], columns=headers)
# --> 317         df.to_csv(f'{self.config.RESULTS_PATH}\{file_name}.csv', index=False, float_format='%.3f')
#     318
#     319     def compare_steps_average_welch_test(self, start_index, end_index):
#
# E:\_ZSSE\Anaconda\envs\pyalcs-experiments-acs2er\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3480             doublequote=doublequote,
#    3481             escapechar=escapechar,
# -> 3482             storage_options=storage_options,
#    3483         )
#    3484
#
# E:\_ZSSE\Anaconda\envs\pyalcs-experiments-acs2er\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# E:\_ZSSE\Anaconda\envs\pyalcs-experiments-acs2er\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     241             errors=self.errors,
#     242             compression=self.compression,
# --> 243             storage_options=self.storage_options,
#     244         ) as handles:
#     245
#
# E:\_ZSSE\Anaconda\envs\pyalcs-experiments-acs2er\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# PermissionError: [Errno 13] Permission denied: 'RESULTS\\COR\\corridor-100-v0\\501\\knowledge95.csv'
